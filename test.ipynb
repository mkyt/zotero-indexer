# %%
from pathlib import Path
import json
import xml.etree.ElementTree as ET

# %%
base = Path('/Users/hiro/Downloads/')
lib_json_f = base / 'My Library.json'
lib_rdf_f = base / 'My Library.rdf'

# %%
lib_json = json.load(open(lib_json_f, 'r'))

# %%
lib_rdf = ET.parse(lib_rdf_f)

# %%
doc_tags = set([r'{http://purl.org/net/biblio#}Book', r'{http://purl.org/net/biblio#}Article', r'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description'])
coll_tag = r'{http://www.zotero.org/namespaces/export#}Collection'

title_tag = r'{http://purl.org/dc/elements/1.1/}title'
link_tag = r'{http://purl.org/rss/1.0/modules/link/}link'
resource_tag = r'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource'
attachment_tag = r'{http://www.zotero.org/namespaces/export#}Attachment'
type_tag = r'{http://purl.org/rss/1.0/modules/link/}type'

about_key = r"{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about"
resource_key = r"{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource"

root = lib_rdf.getroot()
item_id2node = {}

docs = []
colls = []

for child in root:
    if about_key in child.attrib:
        item_id = child.attrib[about_key]
        item_id2node[item_id] = child
        #print(child.tag, item_id)
        if child.tag in doc_tags:
            docs.append(child)
        elif child.tag == coll_tag:
            colls.append(child)
    else:
        print('[ERROR] `about` attribute not found for top-level item!')
        print(child.tag, child.attrib)

# %%
all_docs = []

for doc in docs:
    item_id = doc.attrib[about_key]
    title = doc.find(title_tag).text
    attachments = []
    links = doc.findall(link_tag)
    for link in links:
        link_id = link.attrib[resource_key]
        link_node = item_id2node[link_id]
        if link_node.tag != attachment_tag:
            continue
        rsrc = link_node.find(resource_tag)
        if rsrc is None:
            print('[ERROR] `resource` tag not found for attachment!')
            continue
        resource_path = rsrc.attrib[resource_key]
        resource_path = resource_path.removeprefix('attachments:')

        typ = link_node.find(type_tag)
        if typ is None:
            print('[ERROR] `type` tag not found for attachment!')
            continue
        resource_type = typ.text
        attachments.append({'path': resource_path, 'type': resource_type})
    all_docs.append({
        'id': item_id,
        'title': title,
        'attachments': attachments,
        'tags': set(),
    })
# Out:
# [ERROR] `resource` tag not found for attachment!
# [ERROR] `resource` tag not found for attachment!
# [ERROR] `resource` tag not found for attachment!
# [ERROR] `resource` tag not found for attachment!

# %%
all_docs
# Out:
# [{'id': '#item_1',
#   'title': 'カルボニルストレス代謝障害と統合失調症',
#   'attachments': [{'path': 'Journal Article/新井 et al_2015_カルボニルストレス代謝障害と統合失調症.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_2',
#   'title': '心理学におけるベイズ統計モデリング',
#   'attachments': [{'path': 'Journal Article/裕士_2018_心理学におけるベイズ統計モデリング.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41598-018-38355-z',
#   'title': 'Neurometabolic and functional connectivity basis of prosocial behavior in early adolescence',
#   'attachments': [{'path': 'Journal Article/Okada et al_2019_Neurometabolic and functional connectivity basis of prosocial behavior in early.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/cercor/article/31/6/2812/6082824',
#   'title': 'Pubertal Testosterone and the Structure of the Cerebral Cortex in Young Men',
#   'attachments': [{'path': 'Journal Article/Liao et al_2021_Pubertal Testosterone and the Structure of the Cerebral Cortex in Young Men.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0108838',
#   'title': 'Testosterone Trajectories and Reference Ranges in a Large Longitudinal Sample of Male Adolescents',
#   'attachments': [{'path': 'Journal Article/Khairullah et al_2014_Testosterone Trajectories and Reference Ranges in a Large Longitudinal Sample.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s11682-016-9629-z',
#   'title': 'Human subcortical brain asymmetries in 15,847 people worldwide reveal effects of age and sex',
#   'attachments': [{'path': 'Journal Article/Guadalupe et al_2017_Human subcortical brain asymmetries in 15,847 people worldwide reveal effects.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945214002469',
#   'title': 'Asymmetry within and around the human planum temporale is sexually dimorphic and influenced by genes involved in steroid hormone receptor activity',
#   'attachments': [{'path': 'Journal Article/Guadalupe et al_2015_Asymmetry within and around the human planum temporale is sexually dimorphic.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0046970',
#   'title': 'Developmental Trajectories of Amygdala and Hippocampus from Infancy to Early Adulthood in Healthy Individuals',
#   'attachments': [{'path': 'Journal Article/Uematsu et al_2012_Developmental Trajectories of Amygdala and Hippocampus from Infancy to Early.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1524418113',
#   'title': 'Yes, there is a female and a male brain: Morphology versus functionality',
#   'attachments': [{'path': 'Journal Article/Glezerman_2016_Yes, there is a female and a male brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s11011-015-9692-y',
#   'title': 'A quantitative and qualitative review of the effects of testosterone on the function and structure of the human social-emotional brain',
#   'attachments': [{'path': 'Journal Article/Heany et al_2016_A quantitative and qualitative review of the effects of testosterone on the.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2213158221002254',
#   'title': 'Amygdala substructure volumes in Major Depressive Disorder',
#   'attachments': [{'path': 'Journal Article/Roddy et al_2021_Amygdala substructure volumes in Major Depressive Disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763421000804',
#   'title': 'Dump the “dimorphism”: Comprehensive synthesis of human brain studies reveals few male-female differences beyond size',
#   'attachments': [{'path': 'Journal Article/Eliot et al_2021_Dump the “dimorphism”.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763421003778',
#   'title': 'Socioeconomic status and the developing brain – A systematic review of neuroimaging findings in youth',
#   'attachments': [{'path': 'Journal Article/Rakesh_Whittle_2021_Socioeconomic status and the developing brain – A systematic review of.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0920996420300815',
#   'title': 'Developmental trajectories of subcortical structures in relation to dimensional schizotypy expression along adolescence',
#   'attachments': [{'path': 'Journal Article/Derome et al_2020_Developmental trajectories of subcortical structures in relation to dimensional.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453021004789',
#   'title': 'Associations between testosterone, estradiol, and androgen receptor genotype with amygdala subregions in adolescents',
#   'attachments': [{'path': 'Journal Article/Campbell et al_2022_Associations between testosterone, estradiol, and androgen receptor genotype.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41598-017-14613-4',
#   'title': 'Graph theory reveals amygdala modules consistent with its anatomical subdivisions',
#   'attachments': [{'path': 'Journal Article/Caparelli et al_2017_Graph theory reveals amygdala modules consistent with its anatomical.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811914001980',
#   'title': 'The development of human amygdala functional connectivity at rest from 4 to 23years: A cross-sectional study',
#   'attachments': [{'path': 'Journal Article/Gabard-Durnam et al_2014_The development of human amygdala functional connectivity at rest from 4 to.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/npp201272',
#   'title': 'Amygdala Subregions Tied to SSRI and Placebo Response in Patients with Social Anxiety Disorder',
#   'attachments': [{'path': 'Journal Article/Faria et al_2012_Amygdala Subregions Tied to SSRI and Placebo Response in Patients with Social.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811915003031',
#   'title': 'Developmental sex differences in resting state functional connectivity of amygdala sub-regions',
#   'attachments': [{'path': 'Journal Article/Alarcon et al_2015_Developmental sex differences in resting state functional connectivity of.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811912002029',
#   'title': 'Sex differences in amygdala subregions: Evidence from subregional shape analysis',
#   'attachments': [{'path': 'Journal Article/Kim et al_2012_Sex differences in amygdala subregions.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2451902219302010',
#   'title': 'Distinct Processing of Aversive Experience in Amygdala Subregions',
#   'attachments': [{'path': 'Journal Article/Michely et al_2020_Distinct Processing of Aversive Experience in Amygdala Subregions.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0000307',
#   'title': 'Response Properties of Human Amygdala Subregions: Evidence Based on Functional MRI Combined with Probabilistic Anatomical Maps',
#   'attachments': [{'path': 'Journal Article/Ball et al_2007_Response Properties of Human Amygdala Subregions.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945212002419',
#   'title': 'Amygdala subregions differentially respond and rapidly adapt to threatening voices',
#   'attachments': [{'path': 'Journal Article/Fruhholz_Grandjean_2013_Amygdala subregions differentially respond and rapidly adapt to threatening.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/scan/article-lookup/doi/10.1093/scan/nsv055',
#   'title': 'Functionally distinct amygdala subregions identified using DTI and high-resolution fMRI',
#   'attachments': [{'path': 'Journal Article/Balderston et al_2015_Functionally distinct amygdala subregions identified using DTI and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s00429-020-02208-1',
#   'title': 'Calendar age and puberty-related development of regional gray matter volume and white matter tracts during adolescence',
#   'attachments': [{'path': 'Journal Article/Ando et al_2021_Calendar age and puberty-related development of regional gray matter volume and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0018506X09001767',
#   'title': 'Sexual dimorphism in the adolescent brain: Role of testosterone and androgen receptor in global and local volumes of grey and white matter',
#   'attachments': [{'path': 'Journal Article/Paus et al_2010_Sexual dimorphism in the adolescent brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0083929',
#   'title': 'The Influence of Sex Steroids on Structural Brain Maturation in Adolescence',
#   'attachments': [{'path': 'Journal Article/Koolschijn et al_2014_The Influence of Sex Steroids on Structural Brain Maturation in Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2666497621000485',
#   'title': 'The effects of puberty and its hormones on subcortical brain development',
#   'attachments': [{'path': 'Journal Article/Vijayakumar et al_2021_The effects of puberty and its hormones on subcortical brain development.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453015009245',
#   'title': 'A testosterone-related structural brain phenotype predicts aggressive behavior from childhood to adulthood',
#   'attachments': [{'path': 'Testosterone/Imaging/Nguyen et al_2016_A testosterone-related structural brain phenotype predicts aggressive behavior.pdf',
#     'type': 'application/pdf'},
#    {'path': 'Journal Article/Nguyen et al_2016_A testosterone-related structural brain phenotype predicts aggressive behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811910008542',
#   'title': 'Automatic parcellation of human cortical gyri and sulci using standard anatomical nomenclature',
#   'attachments': [{'path': 'Journal Article/Destrieux et al_2010_Automatic parcellation of human cortical gyri and sulci using standard.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_39',
#   'title': 'ASEBA行動チェックリスト（CBCL：6-18歳用）標準値作成の試み',
#   'attachments': [{'path': 'Journal Article/康子_俊哉_2017_ASEBA行動チェックリスト（CBCL：6-18歳用）標準値作成の試み.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/120006797551/en/',
#   'title': 'Standardization of the Japanese version of the Child Behavior Checklist/4-18',
#   'attachments': [{'path': 'Journal Article/ITANI et al_2001_Standardization of the Japanese version of the Child Behavior Checklist-4-18.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://doi.wiley.com/10.1111/j.1600-0447.2010.01644.x',
#   'title': 'Longitudinal MR study of brain structure and hippocampus volume in major depressive disorder: Longitudinal MR study of brain structure and hippocampus volume in major depressive disorder',
#   'attachments': [{'path': 'Journal Article/Ahdidan et al_2011_Longitudinal MR study of brain structure and hippocampus volume in major.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.tandfonline.com/doi/full/10.3109/10253890.2010.522279',
#   'title': 'Effects of stressful life events on human brain structure: A longitudinal voxel-based morphometry study',
#   'attachments': [{'path': 'Journal Article/Papagni et al_2011_Effects of stressful life events on human brain structure.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1878929313000650',
#   'title': 'Positive parenting predicts the development of adolescent brain structure: A longitudinal study',
#   'attachments': [{'path': 'Journal Article/Whittle et al_2014_Positive parenting predicts the development of adolescent brain structure.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453017308739',
#   'title': 'Prenatal and pubertal testosterone affect brain lateralization',
#   'attachments': [{'path': 'Journal Article/Beking et al_2018_Prenatal and pubertal testosterone affect brain lateralization.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://doi.wiley.com/10.1111/jne.12486',
#   'title': 'Developmental effects of androgens in the human brain',
#   'attachments': [{'path': 'Journal Article/Nguyen_2018_Developmental effects of androgens in the human brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journals.sagepub.com/doi/10.1080/016502598384153',
#   'title': 'Testosterone, Physical Aggression, Dominance, and Physical Development in Early Adolescence',
#   'attachments': [{'path': 'Journal Article/Tremblay et al_1998_Testosterone, Physical Aggression, Dominance, and Physical Development in Early.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945219301984',
#   'title': 'Affective reactivity during adolescence: Associations with age, puberty and testosterone',
#   'attachments': [{'path': 'Journal Article/Vijayakumar et al_2019_Affective reactivity during adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1878929320300219',
#   'title': 'Sex differences in the effects of gonadal hormones on white matter microstructure development in adolescence',
#   'attachments': [{'path': 'Journal Article/Ho et al_2020_Sex differences in the effects of gonadal hormones on white matter.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/cercor/article-lookup/doi/10.1093/cercor/bhs125',
#   'title': 'Testosterone-Related Cortical Maturation Across Childhood and Adolescence',
#   'attachments': [{'path': 'Journal Article/Nguyen et al_2013_Testosterone-Related Cortical Maturation Across Childhood and Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453017313252',
#   'title': 'Unraveling age, puberty and testosterone effects on subcortical brain development across adolescence',
#   'attachments': [{'path': 'Journal Article/Wierenga et al_2018_Unraveling age, puberty and testosterone effects on subcortical brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/endo/article/150/8/3690/2456411',
#   'title': 'Testosterone Programs Adult Social Behavior before and during, But Not after, Adolescence',
#   'attachments': [{'path': 'Journal Article/Schulz et al_2009_Testosterone Programs Adult Social Behavior before and during, But Not after,.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0890856709636352',
#   'title': 'Male Testosterone Linked to High Social Dominance but Low Physical Aggression in Early Adolescence',
#   'attachments': [{'path': 'Journal Article/Schaal et al_1996_Male Testosterone Linked to High Social Dominance but Low Physical Aggression2.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://doi.wiley.com/10.1002/hbm.22575',
#   'title': 'The role of testosterone and estradiol in brain volume changes across adolescence: A longitudinal structural MRI study: Pubertal Hormones and Brain Volume',
#   'attachments': [{'path': 'Journal Article/Herting et al_2014_The role of testosterone and estradiol in brain volume changes across.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0033850',
#   'title': 'Sex Matters during Adolescence: Testosterone-Related Cortical Thickness Maturation Differs between Boys and Girls',
#   'attachments': [{'path': 'Journal Article/Bramen et al_2012_Sex Matters during Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453016309994',
#   'title': 'Sex-specific associations of testosterone with prefrontal-hippocampal development and executive function',
#   'attachments': [{'path': 'Journal Article/Nguyen et al_2017_Sex-specific associations of testosterone with prefrontal-hippocampal.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41467-019-08944-1',
#   'title': 'Atypical functional connectome hierarchy in autism',
#   'attachments': [{'path': 'Journal Article/Hong et al_2019_Atypical functional connectome hierarchy in autism.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811917305463',
#   'title': 'Connectopic mapping with resting-state fMRI',
#   'attachments': [{'path': 'Journal Article/Haak et al_2018_Connectopic mapping with resting-state fMRI.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jneurosci.org/lookup/doi/10.1523/JNEUROSCI.3302-16.2017',
#   'title': 'Development of the Cerebral Cortex across Adolescence: A Multisample Study of Inter-Related Longitudinal Changes in Cortical Volume, Surface Area, and Thickness',
#   'attachments': [{'path': 'Journal Article/Tamnes et al_2017_Development of the Cerebral Cortex across Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://doi.wiley.com/10.1002/hbm.23154',
#   'title': 'Brain development during adolescence: A mixed-longitudinal investigation of cortical thickness, surface area, and volume: Brain Development During Adolescence',
#   'attachments': [{'path': 'Journal Article/Vijayakumar et al_2016_Brain development during adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/nn1099_861',
#   'title': 'Brain development during childhood and adolescence: a longitudinal MRI study',
#   'attachments': [{'path': 'Journal Article/Giedd et al_1999_Brain development during childhood and adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0924977X12001095',
#   'title': 'Testosterone in the brain: Neuroimaging findings and the potential role for neuropsychopharmacology',
#   'attachments': [{'path': 'Journal Article/Hofer et al_2013_Testosterone in the brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s40750-017-0069-9',
#   'title': 'Predicting Social Behavior: Basal and Dynamic Joint Effects of Testosterone and Cortisol',
#   'attachments': [{'path': 'Journal Article/Lozza et al_2017_Predicting Social Behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453020300159',
#   'title': 'Social withdrawal and testosterone levels in early adolescent boys',
#   'attachments': [{'path': 'Journal Article/Hayashi et al_2020_Social withdrawal and testosterone levels in early adolescent boys.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.jneurosci.org/cgi/doi/10.1523/JNEUROSCI.2180-11.2011',
#   'title': 'Mapping Human Cortical Areas In Vivo Based on Myelin Content as Revealed by T1- and T2-Weighted MRI',
#   'attachments': [{'path': 'Journal Article/Glasser_Van Essen_2011_Mapping Human Cortical Areas In Vivo Based on Myelin Content as Revealed by T1-.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811919303714',
#   'title': 'Ciftify: A framework for surface-based analysis of legacy MR acquisitions',
#   'attachments': [{'path': 'Journal Article/Dickie et al_2019_Ciftify.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811913005053',
#   'title': 'The minimal preprocessing pipelines for the Human Connectome Project',
#   'attachments': [{'path': 'Journal Article/Glasser et al_2013_The minimal preprocessing pipelines for the Human Connectome Project.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnhum.2018.00061/full',
#   'title': 'Computational Neuropsychology and Bayesian Inference',
#   'attachments': [{'path': 'Journal Article/Parr et al_2018_Computational Neuropsychology and Bayesian Inference.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-19-530106-9',
#   'title': 'Rhythms of the Brain',
#   'attachments': [{'path': 'Book/Buzsaki_2006_Rhythms of the Brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-578-64400-4',
#   'title': 'Handbook of functional connectivity Magnetic Resonance Imaging methods in CONN',
#   'attachments': [{'path': 'Book/Nieto-Castanon_2020_Handbook of functional connectivity Magnetic Resonance Imaging methods in CONN.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-511-89502-9',
#   'title': 'Handbook of Functional MRI Data Analysis',
#   'attachments': [{'path': 'Book/Poldrack et al_2011_Handbook of Functional MRI Data Analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/neuro.06.004.2008/abstract',
#   'title': 'Representational similarity analysis – connecting the branches of systems neuroscience',
#   'attachments': [{'path': 'Journal Article/Kriegeskorte_2008_Representational similarity analysis – connecting the branches of systems.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pcbi.1003553',
#   'title': 'A Toolbox for Representational Similarity Analysis',
#   'attachments': [{'path': 'Journal Article/Nili et al_2014_A Toolbox for Representational Similarity Analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1608282113',
#   'title': 'Situating the default-mode network along a principal gradient of macroscale cortical organization',
#   'attachments': [{'path': 'Journal Article/Margulies et al_2016_Situating the default-mode network along a principal gradient of macroscale.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.pnas.org/cgi/doi/10.1073/pnas.0500334102',
#   'title': 'Geometric diffusions as a tool for harmonic analysis and structure definition of data: Diffusion maps',
#   'attachments': [{'path': 'Journal Article/Coifman et al_2005_Geometric diffusions as a tool for harmonic analysis and structure definition.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0092867420310771',
#   'title': 'Neuronal Computation Underlying Inferential Reasoning in Humans and Mice',
#   'attachments': [{'path': 'Journal Article/Barron et al_2020_Neuronal Computation Underlying Inferential Reasoning in Humans and Mice.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnhum.2014.00825/abstract',
#   'title': 'Uncertainty in perception and the Hierarchical Gaussian Filter',
#   'attachments': [{'path': 'Journal Article/Mathys et al_2014_Uncertainty in perception and the Hierarchical Gaussian Filter.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnhum.2011.00039/abstract',
#   'title': 'A Bayesian foundation for individual learning under uncertainty',
#   'attachments': [{'path': 'Journal Article/Mathys_2011_A Bayesian foundation for individual learning under uncertainty.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0278584616304468',
#   'title': 'High doses of antipsychotic polypharmacy are related to an increase in serum levels of pentosidine in patients with schizophrenia',
#   'attachments': [{'path': 'Journal Article/Sannohe et al_2017_High doses of antipsychotic polypharmacy are related to an increase in serum.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fpsyt.2018.00082/full',
#   'title': 'Carbonyl Stress and Microinflammation-Related Molecules as Potential Biomarkers in Schizophrenia',
#   'attachments': [{'path': 'Journal Article/Ohnuma et al_2018_Carbonyl Stress and Microinflammation-Related Molecules as Potential Biomarkers.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/schizophreniabulletin/article-lookup/doi/10.1093/schbul/sbt234',
#   'title': 'Significance of Measurements of Peripheral Carbonyl Stress Markers in a Cross-sectional and Longitudinal Study in Patients With Acute-stage Schizophrenia',
#   'attachments': [{'path': 'Journal Article/Katsuta et al_2014_Significance of Measurements of Peripheral Carbonyl Stress Markers in a.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://archpsyc.jamanetwork.com/article.aspx?doi=10.1001/archgenpsychiatry.2010.62',
#   'title': 'Enhanced Carbonyl Stress in a Subpopulation of Schizophrenia',
#   'attachments': [{'path': 'Journal Article/Arai et al_2010_Enhanced Carbonyl Stress in a Subpopulation of Schizophrenia.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0896627311007926',
#   'title': 'Functional Network Organization of the Human Brain',
#   'attachments': [{'path': 'Journal Article/Power et al_2011_Functional Network Organization of the Human Brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41591-020-01175-8',
#   'title': 'State-dependent responses to intracranial brain stimulation in a patient with depression',
#   'attachments': [{'path': 'Journal Article/Scangos et al_2021_State-dependent responses to intracranial brain stimulation in a patient with.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://doi.wiley.com/10.1002/mrm.27146',
#   'title': 'Hemodynamic response function (HRF) variability confounds resting-state fMRI functional connectivity: RANGAPRAKASH et al.',
#   'attachments': [{'path': 'Journal Article/Rangaprakash et al_2018_Hemodynamic response function (HRF) variability confounds resting-state fMRI.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://doi.wiley.com/10.1002/hbm.1024',
#   'title': 'Spatial and temporal independent component analysis of functional MRI data containing a pair of task-related waveforms',
#   'attachments': [{'path': 'Journal Article/Calhoun et al_2001_Spatial and temporal independent component analysis of functional MRI data.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41583-019-0177-6',
#   'title': 'A cross-disorder connectome landscape of brain dysconnectivity',
#   'attachments': [{'path': 'Journal Article/van den Heuvel_Sporns_2019_A cross-disorder connectome landscape of brain dysconnectivity.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://onlinelibrary.wiley.com/doi/10.1111/pcn.13138',
#   'title': 'Recent advances in the application of predictive coding and active inference models within clinical neuroscience',
#   'attachments': [{'path': 'Journal Article/Smith et al_2021_Recent advances in the application of predictive coding and active inference.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://ajp.psychiatryonline.org/doi/10.1176/appi.ajp.2015.14091200',
#   'title': 'Identification of Distinct Psychosis Biotypes Using Brain-Based Biomarkers',
#   'attachments': [{'path': 'Journal Article/Clementz et al_2016_Identification of Distinct Psychosis Biotypes Using Brain-Based Biomarkers.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41467-018-05317-y',
#   'title': 'Linked dimensions of psychopathology and connectivity in functional brain networks',
#   'attachments': [{'path': 'Journal Article/Xia et al_2018_Linked dimensions of psychopathology and connectivity in functional brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/brain/article/143/3/1027/5758311',
#   'title': 'Two distinct neuroanatomical subtypes of schizophrenia revealed using machine learning',
#   'attachments': [{'path': 'Journal Article/Chand et al_2020_Two distinct neuroanatomical subtypes of schizophrenia revealed using machine.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/nm.4246',
#   'title': 'Resting-state connectivity biomarkers define neurophysiological subtypes of depression',
#   'attachments': [{'path': 'Journal Article/Drysdale et al_2017_Resting-state connectivity biomarkers define neurophysiological subtypes of.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.sciencemag.org/lookup/doi/10.1126/science.aan3458',
#   'title': 'Pavlovian conditioning–induced hallucinations result from overweighting of perceptual priors',
#   'attachments': [{'path': 'Journal Article/Powers et al_2017_Pavlovian conditioning–induced hallucinations result from overweighting of.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1705120114',
#   'title': 'Brain network dynamics are hierarchically organized in time',
#   'attachments': [{'path': 'Journal Article/Vidaurre et al_2017_Brain network dynamics are hierarchically organized in time.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41380-020-0803-8',
#   'title': 'Precision weighting of cortical unsigned prediction error signals benefits learning, is mediated by dopamine, and is impaired in psychosis',
#   'attachments': [{'path': 'Journal Article/Haarsma et al_2020_Precision weighting of cortical unsigned prediction error signals benefits.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0920996420304357',
#   'title': 'Enhanced carbonyl stress and disrupted white matter integrity in schizophrenia',
#   'attachments': [{'path': 'Journal Article/Son et al_2020_Enhanced carbonyl stress and disrupted white matter integrity in schizophrenia.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/schizophreniabulletin/article-lookup/doi/10.1093/schbul/sbt129',
#   'title': 'Clinical Features of Schizophrenia With Enhanced Carbonyl Stress',
#   'attachments': [{'path': 'Journal Article/Miyashita et al_2014_Clinical Features of Schizophrenia With Enhanced Carbonyl Stress.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_100',
#   'title': '糖化ストレスマーカーと統合失調症',
#   'attachments': [{'path': 'Journal Article/新井 et al_2016_糖化ストレスマーカーと統合失調症.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_101',
#   'title': '統合失調症患者の一部に見られるカルボニルストレス',
#   'attachments': [{'path': 'Journal Article/新井 et al_2011_統合失調症患者の一部に見られるカルボニルストレス.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_102',
#   'title': 'カルボニルストレス性統合失調症の病態に関する研究',
#   'attachments': [{'path': 'Journal Article/新井 et al_2012_カルボニルストレス性統合失調症の病態に関する研究.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.sciencemag.org/lookup/doi/10.1126/science.1133755',
#   'title': 'Five Rules for the Evolution of Cooperation',
#   'attachments': [{'path': 'Journal Article/Nowak_2006_Five Rules for the Evolution of Cooperation.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-262-13409-5',
#   'title': 'The big book of concepts',
#   'attachments': [{'path': 'Book/Murphy_2002_The big book of concepts.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_106',
#   'title': '統計的仮説検定を用いる心理学研究におけるサンプルサイズ設計',
#   'attachments': [{'path': 'Journal Article/潤一郎_貴充_2018_統計的仮説検定を用いる心理学研究におけるサンプルサイズ設計.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_107',
#   'title': '高次認知研究におけるベイズ的アプローチ',
#   'attachments': [{'path': 'Journal Article/國則_2018_高次認知研究におけるベイズ的アプローチ.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_108',
#   'title': 'ベイズファクターによる心理学的仮説・モデルの評価',
#   'attachments': [{'path': 'Journal Article/謙介_2018_ベイズファクターによる心理学的仮説・モデルの評価.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_109',
#   'title': 'しなやかな臨床試験デザイン：適応型デザインによる効率化',
#   'attachments': [{'path': 'Journal Article/由武_2018_しなやかな臨床試験デザイン：適応型デザインによる効率化.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_110',
#   'title': '臨床心理学と認知モデリング',
#   'attachments': [{'path': 'Journal Article/愛彦_2018_臨床心理学と認知モデリング.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-1-4398-4095-5',
#   'title': 'Bayesian data analysis',
#   'attachments': [{'path': 'Book/Gelman_2014_Bayesian data analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/110007642616/',
#   'title': '学問のクレオール--もしくは亡き友への手紙 (特集 学問への招待)',
#   'attachments': [{'path': 'Journal Article/宮地_2002_学問のクレオール--もしくは亡き友への手紙 (特集 学問への招待).pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-1-4614-6848-6',
#   'title': 'Applied predictive modeling',
#   'attachments': [{'path': 'Book/Kuhn_Johnson_2013_Applied predictive modeling.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnins.2016.00515/full',
#   'title': "A Hitchhiker's Guide to Functional Magnetic Resonance Imaging",
#   'attachments': [{'path': "Journal Article/Soares et al_2016_A Hitchhiker's Guide to Functional Magnetic Resonance Imaging.pdf",
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/120006787160/',
#   'title': '悪性腫瘍を合併した統合失調症患者の臨床的検討',
#   'attachments': [{'path': 'Journal Article/立花 et al_2005_悪性腫瘍を合併した統合失調症患者の臨床的検討.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/110006452479/',
#   'title': '「統合失調症により，治療中に精神療法的関与を必要とした舌癌の1例」',
#   'attachments': [{'path': 'Journal Article/松本 et al_2005_「統合失調症により，治療中に精神療法的関与を必要とした舌癌の1例」.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_117',
#   'title': '身体疾患をもつ方の不安抑うつのケアと精神疾患をもつ方ががんになったときのケア',
#   'attachments': [{'path': 'Journal Article/龍男_2019_身体疾患をもつ方の不安抑うつのケアと精神疾患をもつ方ががんになったときのケア.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_118',
#   'title': '脳 MRI データの統計解析',
#   'attachments': [{'path': 'Journal Article/川口 淳_2013_脳 MRI データの統計解析.pdf',
#     'type': 'application/pdf'},
#    {'path': 'Journal Article/川口 淳_2013_脳 MRI データの統計解析2.pdf',
#     'type': 'application/pdf'},
#    {'path': 'Journal Article/川口 淳_2013_脳 MRI データの統計解析3.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_119',
#   'title': '拡散テンソル画像の基本原理と画像解析',
#   'attachments': [{'path': 'Journal Article/佐藤 et al_2016_拡散テンソル画像の基本原理と画像解析.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_120',
#   'title': 'Diffusion Tensor Imagingを用いた精神疾患の研究',
#   'attachments': [{'path': 'Journal Article/迅_貴_2009_Diffusion Tensor Imagingを用いた精神疾患の研究.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-1-107-01845-7%20978-1-107-60357-8',
#   'title': 'Bayesian cognitive modeling: a practical course',
#   'attachments': [{'path': 'Book/Lee_Wagenmakers_2013_Bayesian cognitive modeling.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-12-405888-0',
#   'title': 'Doing Bayesian data analysis: a tutorial with R, JAGS, and Stan',
#   'attachments': [{'path': 'Book/Kruschke_2015_Doing Bayesian data analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.mitpressjournals.org/doi/10.1162/neco.2007.19.12.3335',
#   'title': 'Bayesian Inference Explains Perception of Unity and Ventriloquism Aftereffect: Identification of Common Sources of Audiovisual Stimuli',
#   'attachments': [{'path': 'Journal Article/Sato et al_2007_Bayesian Inference Explains Perception of Unity and Ventriloquism Aftereffect.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41467-019-12170-0',
#   'title': 'A Bayesian psychophysics model of sense of agency',
#   'attachments': [{'path': 'Journal Article/Legaspi_Toyoizumi_2019_A Bayesian psychophysics model of sense of agency.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-08-048932-2',
#   'title': 'Knowledge Representation and Reasoning.',
#   'attachments': [{'path': 'Book/Brachman_Levesque_2004_Knowledge representation and reasoning.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-262-04199-7',
#   'title': 'Theoretical neuroscience: computational and mathematical modeling of neural systems',
#   'attachments': [{'path': 'Book/Dayan_Abbott_2001_Theoretical neuroscience.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/120005945509/',
#   'title': '心理療法の作用機序',
#   'attachments': [{'path': 'Journal Article/池田_高橋_2007_心理療法の作用機序.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/40021232591/',
#   'title': '伝統的精神医学の理念型とプロトタイプ診断(Westen D) (特集 精神病理学の新課題 : スペクトラムと臨床診断単位の認識論・存在論)',
#   'attachments': [{'path': 'Journal Article/古茶_2017_伝統的精神医学の理念型とプロトタイプ診断(Westen D) (特集 精神病理学の新課題.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/s41380-019-0553-7',
#   'title': 'White matter microstructural alterations across four major psychiatric disorders: mega-analysis study in 2937 individuals',
#   'attachments': [{'path': 'Journal Article/COCORO et al_2020_White matter microstructural alterations across four major psychiatric disorders.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-4-563-00870-3',
#   'title': '統計学演習',
#   'attachments': [{'path': 'Book/村上正康_安田正実_1989_統計学演習.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S105381191600210X',
#   'title': 'Single subject prediction of brain disorders in neuroimaging: Promises and pitfalls',
#   'attachments': [{'path': 'Journal Article/Arbabshirani et al_2017_Single subject prediction of brain disorders in neuroimaging.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811916302877',
#   'title': 'Computational neuroimaging strategies for single patient predictions',
#   'attachments': [{'path': 'Journal Article/Stephan et al_2017_Computational neuroimaging strategies for single patient predictions.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811916001506',
#   'title': 'HYDRA: Revealing heterogeneity of imaging and genetic patterns through a multiple max-margin discriminative analysis framework',
#   'attachments': [{'path': 'Journal Article/Varol et al_2017_HYDRA.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-387-84857-0%20978-0-387-84858-7',
#   'title': 'The Elements of Statistical Learning',
#   'attachments': [{'path': 'Book/Hastie et al_2009_The Elements of Statistical Learning.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://academic.oup.com/ije/article/48/5/1414/5382248',
#   'title': 'Cohort Profile: The Tokyo Teen Cohort study (TTC)',
#   'attachments': [{'path': 'Journal Article/Ando et al_2019_Cohort Profile.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/pcn.12814',
#   'title': 'Population‐neuroscience study of the Tokyo TEEN Cohort (pn‐TTC): Cohort longitudinal study to explore the neurobiological substrates of adolescent psychological and behavioral development',
#   'attachments': [{'path': 'Journal Article/Okada et al_2019_Population‐neuroscience study of the Tokyo TEEN Cohort (pn‐TTC).pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_137',
#   'title': 'Abnormal asymmetries in subcortical brain volume in schizophrenia',
#   'attachments': [{'path': 'Journal Article/Okada et al_2016_Abnormal asymmetries in subcortical brain volume in schizophrenia2.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811919310699',
#   'title': 'Smaller anterior subgenual cingulate volume mediates the effect of girls’ early sexual maturation on negative psychobehavioral outcome',
#   'attachments': [{'path': 'Journal Article/Okada et al_2020_Smaller anterior subgenual cingulate volume mediates the effect of girls’ early.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1878929314000310',
#   'title': 'Methods and considerations for longitudinal structural brain imaging analysis across development',
#   'attachments': [{'path': 'Journal Article/Mills_Tamnes_2014_Methods and considerations for longitudinal structural brain imaging analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.cambridge.org/core/product/identifier/S0033291718000430/type/journal_article',
#   'title': 'What is mood? A computational perspective',
#   'attachments': [{'path': 'Journal Article/Clark et al_2018_What is mood.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-1-4614-7137-0',
#   'title': 'An introduction to statistical learning: with applications in R',
#   'attachments': [{'path': 'Book/James et al_2013_An introduction to statistical learning.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-1-4665-8696-3',
#   'title': 'Advanced R',
#   'attachments': [{'path': 'Book/Wickham_2015_Advanced R.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-262-01802-9',
#   'title': 'Machine learning: a probabilistic perspective',
#   'attachments': [{'path': 'Book/Murphy_2012_Machine learning.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/40020960086/en/',
#   'title': '知的障害者の「責任能力」に関する一考察 : 最決平成27年3月3日LEX/DB25506282を契機として',
#   'attachments': [{'path': 'Journal Article/田川_2015_知的障害者の「責任能力」に関する一考察.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-1-4614-6226-2%20978-1-4614-6227-9',
#   'title': 'Understanding Statistics Using R',
#   'attachments': [{'path': 'Book/Schumacker_Tomek_2013_Understanding Statistics Using R.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/22/1/22_30/_article/-char/ja/',
#   'title': 'Changing Concepts of Decision',
#   'attachments': [{'path': 'Journal Article/Akaishi_2015_Changing Concepts of Decision.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://ci.nii.ac.jp/naid//40020309870',
#   'title': 'うつとストレスに対する計算論的アプローチ : 計算論的精神医学入門 (第28回日本ストレス学会学術総会記録) – (ストレスと認知機能)',
#   'attachments': [{'path': 'Journal Article/国里_2013_うつとストレスに対する計算論的アプローチ.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_148',
#   'title': '計算論的精神医学：脳の数理モデルを用いて精神疾患の病態に迫る',
#   'attachments': [{'path': 'Journal Article/祐一_2019_計算論的精神医学：脳の数理モデルを用いて精神疾患の病態に迫る.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_149',
#   'title': '強化学習と大脳基底核(<特集>運動学習)',
#   'attachments': [{'path': 'Journal Article/和行_賢治_2001_強化学習と大脳基底核(特集運動学習).pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/25/3/25_53/_article/-char/ja/',
#   'title': 'Free Energy Principle and Visual Consciousness',
#   'attachments': [{'path': 'Journal Article/Yoshida_Taguchi_2018_Free Energy Principle and Visual Consciousness.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/25/3/25_113/_article/-char/ja/',
#   'title': 'How Does the Free Energy Principle Inspire Artificial Intelligence?',
#   'attachments': [{'path': 'Journal Article/Oba_2018_How Does the Free Energy Principle Inspire Artificial Intelligence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/25/3/25_104/_article/-char/ja/',
#   'title': 'Modeling Cortical Neural Circuits with the Infomax Principle',
#   'attachments': [{'path': 'Journal Article/Tanaka_2018_Modeling Cortical Neural Circuits with the Infomax Principle.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/25/3/25_86/_article/-char/ja/',
#   'title': 'The Principles of Adaptation in Recognition and Behavior',
#   'attachments': [{'path': 'Journal Article/Shimazaki_2018_The Principles of Adaptation in Recognition and Behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/25/3/25_123/_article/-char/ja/',
#   'title': 'The Free-energy Principle: A Unified Theory of Brain Functions',
#   'attachments': [{'path': 'Journal Article/Inui_2018_The Free-energy Principle.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/10026310423',
#   'title': 'カタトニア(緊張病)症候群の診断と治療',
#   'attachments': [{'path': 'Journal Article/大久保 善朗_2010_カタトニア(緊張病)症候群の診断と治療.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/25/3/25_71/_article/-char/ja/',
#   'title': "Introduction of the Free-Energy Principle: Perception, Action, and Inference of Another's Mind",
#   'attachments': [{'path': 'Journal Article/Isomura_2018_Introduction of the Free-Energy Principle.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/nrn2787',
#   'title': 'The free-energy principle: a unified brain theory?',
#   'attachments': [{'path': 'Journal Article/Friston_2010_The free-energy principle.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'urn:isbn:978-0-7619-5160-5%20978-0-7619-5161-2',
#   'title': 'Introducing ANOVA and ANCOVA: a GLM approach',
#   'attachments': [{'path': 'Book/Rutherford_2001_Introducing ANOVA and ANCOVA.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811908000438',
#   'title': 'Ten simple rules for reporting voxel-based morphometry studies',
#   'attachments': [{'path': 'Journal Article/Ridgway et al_2008_Ten simple rules for reporting voxel-based morphometry studies.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811907001309',
#   'title': 'A default mode of brain function: A brief history of an evolving idea',
#   'attachments': [{'path': 'Journal Article/Raichle_Snyder_2007_A default mode of brain function.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s10334-010-0228-5',
#   'title': 'Resting developments: a review of fMRI post-processing methodologies for spontaneous brain activity',
#   'attachments': [{'path': 'Journal Article/Margulies et al_2010_Resting developments.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://ci.nii.ac.jp/naid/40020383298',
#   'title': 'Basis and perspective for clinical application of resting-state functional MRI',
#   'attachments': [{'path': 'Journal Article/小野田_山口_2015_Basis and perspective for clinical application of resting-state functional MRI.pdf',
#     'type': 'application/pdf'}],
# ...
#  {'id': 'https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2797596',
#   'title': 'Association of Video Gaming With Cognitive Performance Among Children',
#   'attachments': [{'path': 'Journal Article/Chaarani et al_2022_Association of Video Gaming With Cognitive Performance Among Children.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.mdpi.com/2077-0383/11/19/5838',
#   'title': 'Altered Resting-State Network in Adolescents with Problematic Internet Use',
#   'attachments': [{'path': 'Journal Article/Siste et al_2022_Altered Resting-State Network in Adolescents with Problematic Internet Use.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0269979',
#   'title': 'Language processing in Internet use disorder: Task-based fMRI study',
#   'attachments': [{'path': 'Journal Article/Darnai et al_2022_Language processing in Internet use disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.frontiersin.org/articles/10.3389/fpsyg.2021.685137/full',
#   'title': 'Compulsive Internet Use Scale: Psychometric Properties and Associations With Sleeping Patterns, Mental Health, and Well-Being in Lithuanian Medical Students During the Coronavirus Disease 2019 Pandemic',
#   'attachments': [{'path': 'Journal Article/Milasauskiene et al_2021_Compulsive Internet Use Scale.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.frontiersin.org/articles/10.3389/fpsyt.2021.679437/full',
#   'title': 'Structural and Functional Brain Abnormalities in Internet Gaming Disorder and Attention-Deficit/Hyperactivity Disorder: A Comparative Meta-Analysis',
#   'attachments': [{'path': 'Journal Article/Gao et al_2021_Structural and Functional Brain Abnormalities in Internet Gaming Disorder and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://link.springer.com/10.1007/s00787-021-01808-4',
#   'title': 'Bidirectional relationship of problematic Internet use with hyperactivity/inattention and depressive symptoms in adolescents: a population-based cohort study',
#   'attachments': [{'path': 'Journal Article/Morita et al_2022_Bidirectional relationship of problematic Internet use with.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.tandfonline.com/doi/full/10.31887/DCNS.2020.22.2/aweinstein',
#   'title': 'Neurobiological mechanisms underlying internet gaming disorder',
#   'attachments': [{'path': 'Journal Article/Weinstein_Lejoyeux_2020_Neurobiological mechanisms underlying internet gaming disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0031395519301166',
#   'title': 'Behavioral Addictions',
#   'attachments': [{'path': 'Journal Article/Derevensky et al_2019_Behavioral Addictions.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.frontiersin.org/article/10.3389/fnhum.2018.00493/full',
#   'title': 'Neural Correlates of Non-clinical Internet Use in the Motivation Network and Its Modulation by Subclinical Autistic Traits',
#   'attachments': [{'path': 'Journal Article/Fujiwara et al_2018_Neural Correlates of Non-clinical Internet Use in the Motivation Network and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fpsyt.2018.00077/full',
#   'title': 'Altered Gray Matter Volume and Resting-State Connectivity in Individuals With Internet Gaming Disorder: A Voxel-Based Morphometry and Resting-State Functional Magnetic Resonance Imaging Study',
#   'attachments': [{'path': 'Journal Article/Seok_Sohn_2018_Altered Gray Matter Volume and Resting-State Connectivity in Individuals With.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2352853216300438',
#   'title': 'Internet use and problematic Internet use among adolescents in Japan: A nationwide representative survey',
#   'attachments': [{'path': 'Journal Article/Mihara et al_2016_Internet use and problematic Internet use among adolescents in Japan.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763417305870',
#   'title': 'Functional and structural neural alterations in Internet gaming disorder: A systematic review and meta-analysis',
#   'attachments': [{'path': 'Journal Article/Yao et al_2017_Functional and structural neural alterations in Internet gaming disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.wjgnet.com/2220-3206/full/v6/i1/143.htm',
#   'title': 'Internet addiction and problematic Internet use: A systematic review of clinical research',
#   'attachments': [{'path': 'Journal Article/Kuss_Lopez-Fernandez_2016_Internet addiction and problematic Internet use.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s11682-015-9454-9',
#   'title': 'Problematic internet use is associated with structural alterations in the brain reward system in females',
#   'attachments': [{'path': 'Journal Article/Altbacker et al_2016_Problematic internet use is associated with structural alterations in the brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.liebertpub.com/doi/10.1089/cyber.2014.0475',
#   'title': 'Problematic Internet Use and Problematic Online Gaming Are Not the Same: Findings from a Large Nationally Representative Adolescent Sample',
#   'attachments': [{'path': 'Journal Article/Kiraly et al_2014_Problematic Internet Use and Problematic Online Gaming Are Not the Same.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://link.springer.com/10.1007/s11920-014-0508-2',
#   'title': 'Risk Factors of Internet Addiction and the Health Effect of Internet Addiction on Adolescents: A Systematic Review of Longitudinal and Prospective Studies',
#   'attachments': [{'path': 'Journal Article/Lam_2014_Risk Factors of Internet Addiction and the Health Effect of Internet Addiction.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.karger.com/Article/FullText/355076',
#   'title': 'Assessment of Problematic Internet Use by the Compulsive Internet Use Scale and the Internet Addiction Test: A Sample of Problematic and Pathological Gamblers',
#   'attachments': [{'path': 'Journal Article/Guertler et al_2014_Assessment of Problematic Internet Use by the Compulsive Internet Use Scale and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://journals.lww.com/10.1097/YCO.0000000000000663',
#   'title': 'Measuring resilience in children: a review of recent literature and recommendations for future research',
#   'attachments': [{'path': 'Journal Article/King et al_2021_Measuring resilience in children.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://journals.sagepub.com/doi/10.1177/1754073918768878',
#   'title': 'Understanding Emotion in Adolescents: A Review of Emotional Frequency, Intensity, Instability, and Clarity',
#   'attachments': [{'path': 'Journal Article/Bailen et al_2019_Understanding Emotion in Adolescents.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.frontiersin.org/articles/10.3389/fpsyt.2022.865907/full',
#   'title': 'Being Praised for Prosocial Behaviors Longitudinally Reduces Depressive Symptoms in Early Adolescents: A Population-Based Cohort Study',
#   'attachments': [{'path': 'Journal Article/Nagaoka et al_2022_Being Praised for Prosocial Behaviors Longitudinally Reduces Depressive.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2451902221002858',
#   'title': 'Examining Associations Between Amygdala Volumes and Anxiety Symptoms in Autism Spectrum Disorder',
#   'attachments': [{'path': 'Journal Article/Yarger et al_2022_Examining Associations Between Amygdala Volumes and Anxiety Symptoms in Autism.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.nature.com/articles/s41467-021-23994-0',
#   'title': 'Brain structure is linked to the association between family environment and behavioral problems in children in the ABCD study',
#   'attachments': [{'path': 'Journal Article/Gong et al_2021_Brain structure is linked to the association between family environment and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.nature.com/articles/s41380-021-01161-7',
#   'title': 'Age at onset of mental disorders worldwide: large-scale meta-analysis of 192 epidemiological studies',
#   'attachments': [{'path': 'Journal Article/Solmi et al_2022_Age at onset of mental disorders worldwide.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0006322320318126',
#   'title': 'Negative Parenting Affects Adolescent Internalizing Symptoms Through Alterations in Amygdala-Prefrontal Circuitry: A Longitudinal Twin Study',
#   'attachments': [{'path': 'Journal Article/Jiang et al_2021_Negative Parenting Affects Adolescent Internalizing Symptoms Through.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0890856720300186',
#   'title': 'High Psychopathology Subgroup in Young Children With Autism: Associations With Biological Sex and Amygdala Volume',
#   'attachments': [{'path': 'Journal Article/Nordahl et al_2020_High Psychopathology Subgroup in Young Children With Autism.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0225088',
#   'title': 'Unique developmental trajectories of risk behaviors in adolescence and associated outcomes in young adulthood',
#   'attachments': [{'path': 'Journal Article/Peeters et al_2019_Unique developmental trajectories of risk behaviors in adolescence and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://ajp.psychiatryonline.org/doi/10.1176/appi.ajp.2019.19010091',
#   'title': 'Translating Developmental Neuroscience to Understand Risk for Psychiatric Disorders',
#   'attachments': [{'path': 'Journal Article/Meyer_Lee_2019_Translating Developmental Neuroscience to Understand Risk for Psychiatric.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0925492717301439',
#   'title': 'Amygdala volume mediates the relationship between externalizing symptoms and daily smoking in adolescence: A prospective study',
#   'attachments': [{'path': 'Journal Article/Cheetham et al_2018_Amygdala volume mediates the relationship between externalizing symptoms and.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.tandfonline.com/doi/full/10.1080/15374416.2017.1326122',
#   'title': 'Socioeconomic Status, Amygdala Volume, and Internalizing Symptoms in Children and Adolescents',
#   'attachments': [{'path': 'Journal Article/Merz et al_2018_Socioeconomic Status, Amygdala Volume, and Internalizing Symptoms in Children.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0301051117300297',
#   'title': 'Age-related volumetric change of limbic structures and subclinical anxious/depressed symptomatology in typically developing children and adolescents',
#   'attachments': [{'path': 'Journal Article/Albaugh et al_2017_Age-related volumetric change of limbic structures and subclinical.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763416301609',
#   'title': 'The neurobiology of the emotional adolescent: From the inside out',
#   'attachments': [{'path': 'Journal Article/Guyer et al_2016_The neurobiology of the emotional adolescent.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://pnas.org/doi/full/10.1073/pnas.1524907113',
#   'title': 'Pubertal activation of estrogen receptor α in the medial amygdala is essential for the full expression of male social behavior in mice',
#   'attachments': [{'path': 'Journal Article/Sano et al_2016_Pubertal activation of estrogen receptor α in the medial amygdala is essential.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/npp2014236',
#   'title': 'Child Psychiatry Branch of the National Institute of Mental Health Longitudinal Structural Magnetic Resonance Imaging Study of Human Brain Development',
#   'attachments': [{'path': 'Journal Article/Giedd et al_2015_Child Psychiatry Branch of the National Institute of Mental Health Longitudinal.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1054139X14002250',
#   'title': 'Testosterone and Its Effects on Human Male Adolescent Mood and Behavior: A Systematic Review',
#   'attachments': [{'path': 'Journal Article/Duke et al_2014_Testosterone and Its Effects on Human Male Adolescent Mood and Behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0091302213000654',
#   'title': 'Puberty and adolescence as a time of vulnerability to stressors that alter neurobehavioral processes',
#   'attachments': [{'path': 'Journal Article/Holder_Blaustein_2014_Puberty and adolescence as a time of vulnerability to stressors that alter.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811913008720',
#   'title': 'Age-related changes in the structure and function of prefrontal cortex–amygdala circuitry in children and adolescents: A multi-modal imaging approach',
#   'attachments': [{'path': 'Journal Article/Swartz et al_2014_Age-related changes in the structure and function of prefrontal cortex–amygdala.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0018506X13001219',
#   'title': 'The amygdala: An agent of change in adolescent neural networks',
#   'attachments': [{'path': 'Journal Article/Scherf et al_2013_The amygdala.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://www.nature.com/articles/nn.3257',
#   'title': 'Developmental pathways to amygdala-prefrontal function and internalizing symptoms in adolescence',
#   'attachments': [{'path': 'Journal Article/Burghy et al_2012_Developmental pathways to amygdala-prefrontal function and internalizing.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0959438807000414',
#   'title': 'Emotional and cognitive changes during adolescence',
#   'attachments': [{'path': 'Journal Article/Yurgelun-Todd_2007_Emotional and cognitive changes during adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://www.cambridge.org/core/product/identifier/S0954579400003102/type/journal_article',
#   'title': 'Internalizing problems of childhood and adolescence: Prospects, pitfalls, and progress inunderstanding the development of anxiety and depression',
#   'attachments': [{'path': 'Journal Article/Zahn–Waxler et al_2000_Internalizing problems of childhood and adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763400000142',
#   'title': 'The adolescent brain and age-related behavioral manifestations',
#   'attachments': [{'path': 'Journal Article/Spear_2000_The adolescent brain and age-related behavioral manifestations.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': 'http://arxiv.org/abs/2207.09238',
#   'title': 'Formal Algorithms for Transformers',
#   'attachments': [{'path': 'Preprint/Phuong_Hutter_2022_Formal Algorithms for Transformers.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()},
#  {'id': '#item_506',
#   'title': 'Attention is All you Need',
#   'attachments': [{'path': 'Journal Article/Vaswani et al_Attention is All you Need.pdf',
#     'type': 'application/pdf'}],
#   'tags': set()}]

# %%
docid2doc = {}
for doc in all_docs:
    docid2doc[doc['id']] = doc

# %%
coll_dict = {}

hasPart_tag = r'{http://purl.org/dc/terms/}hasPart'

for coll in colls:
    coll_id = coll.attrib[about_key]
    title = coll.find(title_tag).text
    items = []
    children = []
    for part in coll.findall(hasPart_tag):
        part_id = part.attrib[resource_key]
        if part_id.startswith('#collection_'):
            children.append(part_id)
        elif part_id in docid2doc:
            items.append(part_id)
        else:
            print('[ERROR] unknown item id:', part_id)
    coll_dict[coll_id] = {
        'id': coll_id,
        'title': title,
        'items': items,
        'children': children,
    }

# %%
for coll in coll_dict.values():
    for child in coll['children']:
        if child not in coll_dict:
            print('[ERROR] unknown collection id:', child)
        coll_dict[child]['parent'] = coll['id']

# %%
def dfs(coll):
    if 'parent' in coll:
        prefix = coll_dict[coll['parent']]['full_name'] + '/'
    else:
        prefix = ''
    coll['full_name'] = prefix + coll['title']
    for child in coll['children']:
        dfs(coll_dict[child])

for coll in coll_dict.values():
    if 'parent' not in coll: # depth 0 nodes
        dfs(coll)

# %%
for coll in coll_dict.values():
    for item in coll['items']:
        components = coll['full_name'].split('/')
        for i in range(len(components)):
            docid2doc[item]['tags'].add('/'.join(components[:i+1]))

# %%
all_docs
# Out:
# [{'id': '#item_1',
#   'title': 'カルボニルストレス代謝障害と統合失調症',
#   'attachments': [{'path': 'Journal Article/新井 et al_2015_カルボニルストレス代謝障害と統合失調症.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': '#item_2',
#   'title': '心理学におけるベイズ統計モデリング',
#   'attachments': [{'path': 'Journal Article/裕士_2018_心理学におけるベイズ統計モデリング.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': 'http://www.nature.com/articles/s41598-018-38355-z',
#   'title': 'Neurometabolic and functional connectivity basis of prosocial behavior in early adolescence',
#   'attachments': [{'path': 'Journal Article/Okada et al_2019_Neurometabolic and functional connectivity basis of prosocial behavior in early.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'TTC'}},
#  {'id': 'https://academic.oup.com/cercor/article/31/6/2812/6082824',
#   'title': 'Pubertal Testosterone and the Structure of the Cerebral Cortex in Young Men',
#   'attachments': [{'path': 'Journal Article/Liao et al_2021_Pubertal Testosterone and the Structure of the Cerebral Cortex in Young Men.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0108838',
#   'title': 'Testosterone Trajectories and Reference Ranges in a Large Longitudinal Sample of Male Adolescents',
#   'attachments': [{'path': 'Journal Article/Khairullah et al_2014_Testosterone Trajectories and Reference Ranges in a Large Longitudinal Sample.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://link.springer.com/10.1007/s11682-016-9629-z',
#   'title': 'Human subcortical brain asymmetries in 15,847 people worldwide reveal effects of age and sex',
#   'attachments': [{'path': 'Journal Article/Guadalupe et al_2017_Human subcortical brain asymmetries in 15,847 people worldwide reveal effects.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945214002469',
#   'title': 'Asymmetry within and around the human planum temporale is sexually dimorphic and influenced by genes involved in steroid hormone receptor activity',
#   'attachments': [{'path': 'Journal Article/Guadalupe et al_2015_Asymmetry within and around the human planum temporale is sexually dimorphic.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0046970',
#   'title': 'Developmental Trajectories of Amygdala and Hippocampus from Infancy to Early Adulthood in Healthy Individuals',
#   'attachments': [{'path': 'Journal Article/Uematsu et al_2012_Developmental Trajectories of Amygdala and Hippocampus from Infancy to Early.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1524418113',
#   'title': 'Yes, there is a female and a male brain: Morphology versus functionality',
#   'attachments': [{'path': 'Journal Article/Glezerman_2016_Yes, there is a female and a male brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://link.springer.com/10.1007/s11011-015-9692-y',
#   'title': 'A quantitative and qualitative review of the effects of testosterone on the function and structure of the human social-emotional brain',
#   'attachments': [{'path': 'Journal Article/Heany et al_2016_A quantitative and qualitative review of the effects of testosterone on the.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2213158221002254',
#   'title': 'Amygdala substructure volumes in Major Depressive Disorder',
#   'attachments': [{'path': 'Journal Article/Roddy et al_2021_Amygdala substructure volumes in Major Depressive Disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763421000804',
#   'title': 'Dump the “dimorphism”: Comprehensive synthesis of human brain studies reveals few male-female differences beyond size',
#   'attachments': [{'path': 'Journal Article/Eliot et al_2021_Dump the “dimorphism”.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763421003778',
#   'title': 'Socioeconomic status and the developing brain – A systematic review of neuroimaging findings in youth',
#   'attachments': [{'path': 'Journal Article/Rakesh_Whittle_2021_Socioeconomic status and the developing brain – A systematic review of.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0920996420300815',
#   'title': 'Developmental trajectories of subcortical structures in relation to dimensional schizotypy expression along adolescence',
#   'attachments': [{'path': 'Journal Article/Derome et al_2020_Developmental trajectories of subcortical structures in relation to dimensional.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453021004789',
#   'title': 'Associations between testosterone, estradiol, and androgen receptor genotype with amygdala subregions in adolescents',
#   'attachments': [{'path': 'Journal Article/Campbell et al_2022_Associations between testosterone, estradiol, and androgen receptor genotype.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T', 'Testosterone'}},
#  {'id': 'http://www.nature.com/articles/s41598-017-14613-4',
#   'title': 'Graph theory reveals amygdala modules consistent with its anatomical subdivisions',
#   'attachments': [{'path': 'Journal Article/Caparelli et al_2017_Graph theory reveals amygdala modules consistent with its anatomical.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811914001980',
#   'title': 'The development of human amygdala functional connectivity at rest from 4 to 23years: A cross-sectional study',
#   'attachments': [{'path': 'Journal Article/Gabard-Durnam et al_2014_The development of human amygdala functional connectivity at rest from 4 to.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg', 'Testosterone'}},
#  {'id': 'http://www.nature.com/articles/npp201272',
#   'title': 'Amygdala Subregions Tied to SSRI and Placebo Response in Patients with Social Anxiety Disorder',
#   'attachments': [{'path': 'Journal Article/Faria et al_2012_Amygdala Subregions Tied to SSRI and Placebo Response in Patients with Social.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg', 'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811915003031',
#   'title': 'Developmental sex differences in resting state functional connectivity of amygdala sub-regions',
#   'attachments': [{'path': 'Journal Article/Alarcon et al_2015_Developmental sex differences in resting state functional connectivity of.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg', 'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811912002029',
#   'title': 'Sex differences in amygdala subregions: Evidence from subregional shape analysis',
#   'attachments': [{'path': 'Journal Article/Kim et al_2012_Sex differences in amygdala subregions.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg', 'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2451902219302010',
#   'title': 'Distinct Processing of Aversive Experience in Amygdala Subregions',
#   'attachments': [{'path': 'Journal Article/Michely et al_2020_Distinct Processing of Aversive Experience in Amygdala Subregions.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg', 'Testosterone'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0000307',
#   'title': 'Response Properties of Human Amygdala Subregions: Evidence Based on Functional MRI Combined with Probabilistic Anatomical Maps',
#   'attachments': [{'path': 'Journal Article/Ball et al_2007_Response Properties of Human Amygdala Subregions.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945212002419',
#   'title': 'Amygdala subregions differentially respond and rapidly adapt to threatening voices',
#   'attachments': [{'path': 'Journal Article/Fruhholz_Grandjean_2013_Amygdala subregions differentially respond and rapidly adapt to threatening.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg'}},
#  {'id': 'https://academic.oup.com/scan/article-lookup/doi/10.1093/scan/nsv055',
#   'title': 'Functionally distinct amygdala subregions identified using DTI and high-resolution fMRI',
#   'attachments': [{'path': 'Journal Article/Balderston et al_2015_Functionally distinct amygdala subregions identified using DTI and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/Amyg'}},
#  {'id': 'http://link.springer.com/10.1007/s00429-020-02208-1',
#   'title': 'Calendar age and puberty-related development of regional gray matter volume and white matter tracts during adolescence',
#   'attachments': [{'path': 'Journal Article/Ando et al_2021_Calendar age and puberty-related development of regional gray matter volume and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0018506X09001767',
#   'title': 'Sexual dimorphism in the adolescent brain: Role of testosterone and androgen receptor in global and local volumes of grey and white matter',
#   'attachments': [{'path': 'Journal Article/Paus et al_2010_Sexual dimorphism in the adolescent brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0083929',
#   'title': 'The Influence of Sex Steroids on Structural Brain Maturation in Adolescence',
#   'attachments': [{'path': 'Journal Article/Koolschijn et al_2014_The Influence of Sex Steroids on Structural Brain Maturation in Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2666497621000485',
#   'title': 'The effects of puberty and its hormones on subcortical brain development',
#   'attachments': [{'path': 'Journal Article/Vijayakumar et al_2021_The effects of puberty and its hormones on subcortical brain development.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453015009245',
#   'title': 'A testosterone-related structural brain phenotype predicts aggressive behavior from childhood to adulthood',
#   'attachments': [{'path': 'Testosterone/Imaging/Nguyen et al_2016_A testosterone-related structural brain phenotype predicts aggressive behavior.pdf',
#     'type': 'application/pdf'},
#    {'path': 'Journal Article/Nguyen et al_2016_A testosterone-related structural brain phenotype predicts aggressive behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811910008542',
#   'title': 'Automatic parcellation of human cortical gyri and sulci using standard anatomical nomenclature',
#   'attachments': [{'path': 'Journal Article/Destrieux et al_2010_Automatic parcellation of human cortical gyri and sulci using standard.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure'}},
#  {'id': '#item_39',
#   'title': 'ASEBA行動チェックリスト（CBCL：6-18歳用）標準値作成の試み',
#   'attachments': [{'path': 'Journal Article/康子_俊哉_2017_ASEBA行動チェックリスト（CBCL：6-18歳用）標準値作成の試み.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'PsychologicalMeasures'}},
#  {'id': 'https://ci.nii.ac.jp/naid/120006797551/en/',
#   'title': 'Standardization of the Japanese version of the Child Behavior Checklist/4-18',
#   'attachments': [{'path': 'Journal Article/ITANI et al_2001_Standardization of the Japanese version of the Child Behavior Checklist-4-18.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'PsychologicalMeasures'}},
#  {'id': 'http://doi.wiley.com/10.1111/j.1600-0447.2010.01644.x',
#   'title': 'Longitudinal MR study of brain structure and hippocampus volume in major depressive disorder: Longitudinal MR study of brain structure and hippocampus volume in major depressive disorder',
#   'attachments': [{'path': 'Journal Article/Ahdidan et al_2011_Longitudinal MR study of brain structure and hippocampus volume in major.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Longitudinal'}},
#  {'id': 'http://www.tandfonline.com/doi/full/10.3109/10253890.2010.522279',
#   'title': 'Effects of stressful life events on human brain structure: A longitudinal voxel-based morphometry study',
#   'attachments': [{'path': 'Journal Article/Papagni et al_2011_Effects of stressful life events on human brain structure.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Longitudinal'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1878929313000650',
#   'title': 'Positive parenting predicts the development of adolescent brain structure: A longitudinal study',
#   'attachments': [{'path': 'Journal Article/Whittle et al_2014_Positive parenting predicts the development of adolescent brain structure.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Longitudinal'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453017308739',
#   'title': 'Prenatal and pubertal testosterone affect brain lateralization',
#   'attachments': [{'path': 'Journal Article/Beking et al_2018_Prenatal and pubertal testosterone affect brain lateralization.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://doi.wiley.com/10.1111/jne.12486',
#   'title': 'Developmental effects of androgens in the human brain',
#   'attachments': [{'path': 'Journal Article/Nguyen_2018_Developmental effects of androgens in the human brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://journals.sagepub.com/doi/10.1080/016502598384153',
#   'title': 'Testosterone, Physical Aggression, Dominance, and Physical Development in Early Adolescence',
#   'attachments': [{'path': 'Journal Article/Tremblay et al_1998_Testosterone, Physical Aggression, Dominance, and Physical Development in Early.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945219301984',
#   'title': 'Affective reactivity during adolescence: Associations with age, puberty and testosterone',
#   'attachments': [{'path': 'Journal Article/Vijayakumar et al_2019_Affective reactivity during adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1878929320300219',
#   'title': 'Sex differences in the effects of gonadal hormones on white matter microstructure development in adolescence',
#   'attachments': [{'path': 'Journal Article/Ho et al_2020_Sex differences in the effects of gonadal hormones on white matter.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://academic.oup.com/cercor/article-lookup/doi/10.1093/cercor/bhs125',
#   'title': 'Testosterone-Related Cortical Maturation Across Childhood and Adolescence',
#   'attachments': [{'path': 'Journal Article/Nguyen et al_2013_Testosterone-Related Cortical Maturation Across Childhood and Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453017313252',
#   'title': 'Unraveling age, puberty and testosterone effects on subcortical brain development across adolescence',
#   'attachments': [{'path': 'Journal Article/Wierenga et al_2018_Unraveling age, puberty and testosterone effects on subcortical brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://academic.oup.com/endo/article/150/8/3690/2456411',
#   'title': 'Testosterone Programs Adult Social Behavior before and during, But Not after, Adolescence',
#   'attachments': [{'path': 'Journal Article/Schulz et al_2009_Testosterone Programs Adult Social Behavior before and during, But Not after,.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0890856709636352',
#   'title': 'Male Testosterone Linked to High Social Dominance but Low Physical Aggression in Early Adolescence',
#   'attachments': [{'path': 'Journal Article/Schaal et al_1996_Male Testosterone Linked to High Social Dominance but Low Physical Aggression2.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://doi.wiley.com/10.1002/hbm.22575',
#   'title': 'The role of testosterone and estradiol in brain volume changes across adolescence: A longitudinal structural MRI study: Pubertal Hormones and Brain Volume',
#   'attachments': [{'path': 'Journal Article/Herting et al_2014_The role of testosterone and estradiol in brain volume changes across.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0033850',
#   'title': 'Sex Matters during Adolescence: Testosterone-Related Cortical Thickness Maturation Differs between Boys and Girls',
#   'attachments': [{'path': 'Journal Article/Bramen et al_2012_Sex Matters during Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453016309994',
#   'title': 'Sex-specific associations of testosterone with prefrontal-hippocampal development and executive function',
#   'attachments': [{'path': 'Journal Article/Nguyen et al_2017_Sex-specific associations of testosterone with prefrontal-hippocampal.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://www.nature.com/articles/s41467-019-08944-1',
#   'title': 'Atypical functional connectome hierarchy in autism',
#   'attachments': [{'path': 'Journal Article/Hong et al_2019_Atypical functional connectome hierarchy in autism.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven',
#    '🖥️Computational Psychiatry/Data-driven/Gradient'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811917305463',
#   'title': 'Connectopic mapping with resting-state fMRI',
#   'attachments': [{'path': 'Journal Article/Haak et al_2018_Connectopic mapping with resting-state fMRI.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven',
#    '🖥️Computational Psychiatry/Data-driven/Gradient'}},
#  {'id': 'https://www.jneurosci.org/lookup/doi/10.1523/JNEUROSCI.3302-16.2017',
#   'title': 'Development of the Cerebral Cortex across Adolescence: A Multisample Study of Inter-Related Longitudinal Changes in Cortical Volume, Surface Area, and Thickness',
#   'attachments': [{'path': 'Journal Article/Tamnes et al_2017_Development of the Cerebral Cortex across Adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure', 'MRI/structure/Adolescent'}},
#  {'id': 'http://doi.wiley.com/10.1002/hbm.23154',
#   'title': 'Brain development during adolescence: A mixed-longitudinal investigation of cortical thickness, surface area, and volume: Brain Development During Adolescence',
#   'attachments': [{'path': 'Journal Article/Vijayakumar et al_2016_Brain development during adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure', 'MRI/structure/Adolescent'}},
#  {'id': 'http://www.nature.com/articles/nn1099_861',
#   'title': 'Brain development during childhood and adolescence: a longitudinal MRI study',
#   'attachments': [{'path': 'Journal Article/Giedd et al_1999_Brain development during childhood and adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure', 'MRI/structure/Adolescent'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0924977X12001095',
#   'title': 'Testosterone in the brain: Neuroimaging findings and the potential role for neuropsychopharmacology',
#   'attachments': [{'path': 'Journal Article/Hofer et al_2013_Testosterone in the brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'http://link.springer.com/10.1007/s40750-017-0069-9',
#   'title': 'Predicting Social Behavior: Basal and Dynamic Joint Effects of Testosterone and Cortisol',
#   'attachments': [{'path': 'Journal Article/Lozza et al_2017_Predicting Social Behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Testosterone'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453020300159',
#   'title': 'Social withdrawal and testosterone levels in early adolescent boys',
#   'attachments': [{'path': 'Journal Article/Hayashi et al_2020_Social withdrawal and testosterone levels in early adolescent boys.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'TTC', 'Testosterone'}},
#  {'id': 'http://www.jneurosci.org/cgi/doi/10.1523/JNEUROSCI.2180-11.2011',
#   'title': 'Mapping Human Cortical Areas In Vivo Based on Myelin Content as Revealed by T1- and T2-Weighted MRI',
#   'attachments': [{'path': 'Journal Article/Glasser_Van Essen_2011_Mapping Human Cortical Areas In Vivo Based on Myelin Content as Revealed by T1-.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/HCP'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811919303714',
#   'title': 'Ciftify: A framework for surface-based analysis of legacy MR acquisitions',
#   'attachments': [{'path': 'Journal Article/Dickie et al_2019_Ciftify.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/HCP'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811913005053',
#   'title': 'The minimal preprocessing pipelines for the Human Connectome Project',
#   'attachments': [{'path': 'Journal Article/Glasser et al_2013_The minimal preprocessing pipelines for the Human Connectome Project.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/HCP'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnhum.2018.00061/full',
#   'title': 'Computational Neuropsychology and Bayesian Inference',
#   'attachments': [{'path': 'Journal Article/Parr et al_2018_Computational Neuropsychology and Bayesian Inference.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'urn:isbn:978-0-19-530106-9',
#   'title': 'Rhythms of the Brain',
#   'attachments': [{'path': 'Book/Buzsaki_2006_Rhythms of the Brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🧠Basic Neuroscience'}},
#  {'id': 'urn:isbn:978-0-578-64400-4',
#   'title': 'Handbook of functional connectivity Magnetic Resonance Imaging methods in CONN',
#   'attachments': [{'path': 'Book/Nieto-Castanon_2020_Handbook of functional connectivity Magnetic Resonance Imaging methods in CONN.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/functional', 'MRI/functional/Methodology'}},
#  {'id': 'urn:isbn:978-0-511-89502-9',
#   'title': 'Handbook of Functional MRI Data Analysis',
#   'attachments': [{'path': 'Book/Poldrack et al_2011_Handbook of Functional MRI Data Analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/functional', 'MRI/functional/Methodology'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/neuro.06.004.2008/abstract',
#   'title': 'Representational similarity analysis – connecting the branches of systems neuroscience',
#   'attachments': [{'path': 'Journal Article/Kriegeskorte_2008_Representational similarity analysis – connecting the branches of systems.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pcbi.1003553',
#   'title': 'A Toolbox for Representational Similarity Analysis',
#   'attachments': [{'path': 'Journal Article/Nili et al_2014_A Toolbox for Representational Similarity Analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven'}},
#  {'id': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1608282113',
#   'title': 'Situating the default-mode network along a principal gradient of macroscale cortical organization',
#   'attachments': [{'path': 'Journal Article/Margulies et al_2016_Situating the default-mode network along a principal gradient of macroscale.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven',
#    '🖥️Computational Psychiatry/Data-driven/Gradient'}},
#  {'id': 'http://www.pnas.org/cgi/doi/10.1073/pnas.0500334102',
#   'title': 'Geometric diffusions as a tool for harmonic analysis and structure definition of data: Diffusion maps',
#   'attachments': [{'path': 'Journal Article/Coifman et al_2005_Geometric diffusions as a tool for harmonic analysis and structure definition.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven',
#    '🖥️Computational Psychiatry/Data-driven/Gradient'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0092867420310771',
#   'title': 'Neuronal Computation Underlying Inferential Reasoning in Humans and Mice',
#   'attachments': [{'path': 'Journal Article/Barron et al_2020_Neuronal Computation Underlying Inferential Reasoning in Humans and Mice.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/animal'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnhum.2014.00825/abstract',
#   'title': 'Uncertainty in perception and the Hierarchical Gaussian Filter',
#   'attachments': [{'path': 'Journal Article/Mathys et al_2014_Uncertainty in perception and the Hierarchical Gaussian Filter.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnhum.2011.00039/abstract',
#   'title': 'A Bayesian foundation for individual learning under uncertainty',
#   'attachments': [{'path': 'Journal Article/Mathys_2011_A Bayesian foundation for individual learning under uncertainty.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0278584616304468',
#   'title': 'High doses of antipsychotic polypharmacy are related to an increase in serum levels of pentosidine in patients with schizophrenia',
#   'attachments': [{'path': 'Journal Article/Sannohe et al_2017_High doses of antipsychotic polypharmacy are related to an increase in serum.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fpsyt.2018.00082/full',
#   'title': 'Carbonyl Stress and Microinflammation-Related Molecules as Potential Biomarkers in Schizophrenia',
#   'attachments': [{'path': 'Journal Article/Ohnuma et al_2018_Carbonyl Stress and Microinflammation-Related Molecules as Potential Biomarkers.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': 'https://academic.oup.com/schizophreniabulletin/article-lookup/doi/10.1093/schbul/sbt234',
#   'title': 'Significance of Measurements of Peripheral Carbonyl Stress Markers in a Cross-sectional and Longitudinal Study in Patients With Acute-stage Schizophrenia',
#   'attachments': [{'path': 'Journal Article/Katsuta et al_2014_Significance of Measurements of Peripheral Carbonyl Stress Markers in a.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': 'http://archpsyc.jamanetwork.com/article.aspx?doi=10.1001/archgenpsychiatry.2010.62',
#   'title': 'Enhanced Carbonyl Stress in a Subpopulation of Schizophrenia',
#   'attachments': [{'path': 'Journal Article/Arai et al_2010_Enhanced Carbonyl Stress in a Subpopulation of Schizophrenia.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0896627311007926',
#   'title': 'Functional Network Organization of the Human Brain',
#   'attachments': [{'path': 'Journal Article/Power et al_2011_Functional Network Organization of the Human Brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/functional', 'MRI/functional/Methodology'}},
#  {'id': 'http://www.nature.com/articles/s41591-020-01175-8',
#   'title': 'State-dependent responses to intracranial brain stimulation in a patient with depression',
#   'attachments': [{'path': 'Journal Article/Scangos et al_2021_State-dependent responses to intracranial brain stimulation in a patient with.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🏥Clinical Psychiatry', '🏥Clinical Psychiatry/Brain Stimulation'}},
#  {'id': 'http://doi.wiley.com/10.1002/mrm.27146',
#   'title': 'Hemodynamic response function (HRF) variability confounds resting-state fMRI functional connectivity: RANGAPRAKASH et al.',
#   'attachments': [{'path': 'Journal Article/Rangaprakash et al_2018_Hemodynamic response function (HRF) variability confounds resting-state fMRI.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/functional', 'MRI/functional/Methodology'}},
#  {'id': 'http://doi.wiley.com/10.1002/hbm.1024',
#   'title': 'Spatial and temporal independent component analysis of functional MRI data containing a pair of task-related waveforms',
#   'attachments': [{'path': 'Journal Article/Calhoun et al_2001_Spatial and temporal independent component analysis of functional MRI data.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/functional', 'MRI/functional/Methodology'}},
#  {'id': 'http://www.nature.com/articles/s41583-019-0177-6',
#   'title': 'A cross-disorder connectome landscape of brain dysconnectivity',
#   'attachments': [{'path': 'Journal Article/van den Heuvel_Sporns_2019_A cross-disorder connectome landscape of brain dysconnectivity.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Graph-theory'}},
#  {'id': 'https://onlinelibrary.wiley.com/doi/10.1111/pcn.13138',
#   'title': 'Recent advances in the application of predictive coding and active inference models within clinical neuroscience',
#   'attachments': [{'path': 'Journal Article/Smith et al_2021_Recent advances in the application of predictive coding and active inference.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Free Energy Principle'}},
#  {'id': 'http://ajp.psychiatryonline.org/doi/10.1176/appi.ajp.2015.14091200',
#   'title': 'Identification of Distinct Psychosis Biotypes Using Brain-Based Biomarkers',
#   'attachments': [{'path': 'Journal Article/Clementz et al_2016_Identification of Distinct Psychosis Biotypes Using Brain-Based Biomarkers.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven'}},
#  {'id': 'http://www.nature.com/articles/s41467-018-05317-y',
#   'title': 'Linked dimensions of psychopathology and connectivity in functional brain networks',
#   'attachments': [{'path': 'Journal Article/Xia et al_2018_Linked dimensions of psychopathology and connectivity in functional brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven'}},
#  {'id': 'https://academic.oup.com/brain/article/143/3/1027/5758311',
#   'title': 'Two distinct neuroanatomical subtypes of schizophrenia revealed using machine learning',
#   'attachments': [{'path': 'Journal Article/Chand et al_2020_Two distinct neuroanatomical subtypes of schizophrenia revealed using machine.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven'}},
#  {'id': 'http://www.nature.com/articles/nm.4246',
#   'title': 'Resting-state connectivity biomarkers define neurophysiological subtypes of depression',
#   'attachments': [{'path': 'Journal Article/Drysdale et al_2017_Resting-state connectivity biomarkers define neurophysiological subtypes of.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Data-driven'}},
#  {'id': 'https://www.sciencemag.org/lookup/doi/10.1126/science.aan3458',
#   'title': 'Pavlovian conditioning–induced hallucinations result from overweighting of perceptual priors',
#   'attachments': [{'path': 'Journal Article/Powers et al_2017_Pavlovian conditioning–induced hallucinations result from overweighting of.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1705120114',
#   'title': 'Brain network dynamics are hierarchically organized in time',
#   'attachments': [{'path': 'Journal Article/Vidaurre et al_2017_Brain network dynamics are hierarchically organized in time.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Machine Learning'}},
#  {'id': 'http://www.nature.com/articles/s41380-020-0803-8',
#   'title': 'Precision weighting of cortical unsigned prediction error signals benefits learning, is mediated by dopamine, and is impaired in psychosis',
#   'attachments': [{'path': 'Journal Article/Haarsma et al_2020_Precision weighting of cortical unsigned prediction error signals benefits.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0920996420304357',
#   'title': 'Enhanced carbonyl stress and disrupted white matter integrity in schizophrenia',
#   'attachments': [{'path': 'Journal Article/Son et al_2020_Enhanced carbonyl stress and disrupted white matter integrity in schizophrenia.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': 'https://academic.oup.com/schizophreniabulletin/article-lookup/doi/10.1093/schbul/sbt129',
#   'title': 'Clinical Features of Schizophrenia With Enhanced Carbonyl Stress',
#   'attachments': [{'path': 'Journal Article/Miyashita et al_2014_Clinical Features of Schizophrenia With Enhanced Carbonyl Stress.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': '#item_100',
#   'title': '糖化ストレスマーカーと統合失調症',
#   'attachments': [{'path': 'Journal Article/新井 et al_2016_糖化ストレスマーカーと統合失調症.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': '#item_101',
#   'title': '統合失調症患者の一部に見られるカルボニルストレス',
#   'attachments': [{'path': 'Journal Article/新井 et al_2011_統合失調症患者の一部に見られるカルボニルストレス.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': '#item_102',
#   'title': 'カルボニルストレス性統合失調症の病態に関する研究',
#   'attachments': [{'path': 'Journal Article/新井 et al_2012_カルボニルストレス性統合失調症の病態に関する研究.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Carbonyl Stress'}},
#  {'id': 'https://www.sciencemag.org/lookup/doi/10.1126/science.1133755',
#   'title': 'Five Rules for the Evolution of Cooperation',
#   'attachments': [{'path': 'Journal Article/Nowak_2006_Five Rules for the Evolution of Cooperation.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Evolution'}},
#  {'id': 'urn:isbn:978-0-262-13409-5',
#   'title': 'The big book of concepts',
#   'attachments': [{'path': 'Book/Murphy_2002_The big book of concepts.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': '#item_106',
#   'title': '統計的仮説検定を用いる心理学研究におけるサンプルサイズ設計',
#   'attachments': [{'path': 'Journal Article/潤一郎_貴充_2018_統計的仮説検定を用いる心理学研究におけるサンプルサイズ設計.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': '#item_107',
#   'title': '高次認知研究におけるベイズ的アプローチ',
#   'attachments': [{'path': 'Journal Article/國則_2018_高次認知研究におけるベイズ的アプローチ.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': '#item_108',
#   'title': 'ベイズファクターによる心理学的仮説・モデルの評価',
#   'attachments': [{'path': 'Journal Article/謙介_2018_ベイズファクターによる心理学的仮説・モデルの評価.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': '#item_109',
#   'title': 'しなやかな臨床試験デザイン：適応型デザインによる効率化',
#   'attachments': [{'path': 'Journal Article/由武_2018_しなやかな臨床試験デザイン：適応型デザインによる効率化.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': '#item_110',
#   'title': '臨床心理学と認知モデリング',
#   'attachments': [{'path': 'Journal Article/愛彦_2018_臨床心理学と認知モデリング.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Psychology'}},
#  {'id': 'urn:isbn:978-1-4398-4095-5',
#   'title': 'Bayesian data analysis',
#   'attachments': [{'path': 'Book/Gelman_2014_Bayesian data analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'https://ci.nii.ac.jp/naid/110007642616/',
#   'title': '学問のクレオール--もしくは亡き友への手紙 (特集 学問への招待)',
#   'attachments': [{'path': 'Journal Article/宮地_2002_学問のクレオール--もしくは亡き友への手紙 (特集 学問への招待).pdf',
#     'type': 'application/pdf'}],
#   'tags': {'社会科学'}},
#  {'id': 'urn:isbn:978-1-4614-6848-6',
#   'title': 'Applied predictive modeling',
#   'attachments': [{'path': 'Book/Kuhn_Johnson_2013_Applied predictive modeling.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fnins.2016.00515/full',
#   'title': "A Hitchhiker's Guide to Functional Magnetic Resonance Imaging",
#   'attachments': [{'path': "Journal Article/Soares et al_2016_A Hitchhiker's Guide to Functional Magnetic Resonance Imaging.pdf",
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/functional'}},
#  {'id': 'https://ci.nii.ac.jp/naid/120006787160/',
#   'title': '悪性腫瘍を合併した統合失調症患者の臨床的検討',
#   'attachments': [{'path': 'Journal Article/立花 et al_2005_悪性腫瘍を合併した統合失調症患者の臨床的検討.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🏥Clinical Psychiatry', '🏥Clinical Psychiatry/Psycho-oncology'}},
#  {'id': 'https://ci.nii.ac.jp/naid/110006452479/',
#   'title': '「統合失調症により，治療中に精神療法的関与を必要とした舌癌の1例」',
#   'attachments': [{'path': 'Journal Article/松本 et al_2005_「統合失調症により，治療中に精神療法的関与を必要とした舌癌の1例」.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🏥Clinical Psychiatry', '🏥Clinical Psychiatry/Psycho-oncology'}},
#  {'id': '#item_117',
#   'title': '身体疾患をもつ方の不安抑うつのケアと精神疾患をもつ方ががんになったときのケア',
#   'attachments': [{'path': 'Journal Article/龍男_2019_身体疾患をもつ方の不安抑うつのケアと精神疾患をもつ方ががんになったときのケア.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🏥Clinical Psychiatry', '🏥Clinical Psychiatry/Psycho-oncology'}},
#  {'id': '#item_118',
#   'title': '脳 MRI データの統計解析',
#   'attachments': [{'path': 'Journal Article/川口 淳_2013_脳 MRI データの統計解析.pdf',
#     'type': 'application/pdf'},
#    {'path': 'Journal Article/川口 淳_2013_脳 MRI データの統計解析2.pdf',
#     'type': 'application/pdf'},
#    {'path': 'Journal Article/川口 淳_2013_脳 MRI データの統計解析3.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure'}},
#  {'id': '#item_119',
#   'title': '拡散テンソル画像の基本原理と画像解析',
#   'attachments': [{'path': 'Journal Article/佐藤 et al_2016_拡散テンソル画像の基本原理と画像解析.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/diffusion'}},
#  {'id': '#item_120',
#   'title': 'Diffusion Tensor Imagingを用いた精神疾患の研究',
#   'attachments': [{'path': 'Journal Article/迅_貴_2009_Diffusion Tensor Imagingを用いた精神疾患の研究.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/diffusion'}},
#  {'id': 'urn:isbn:978-1-107-01845-7%20978-1-107-60357-8',
#   'title': 'Bayesian cognitive modeling: a practical course',
#   'attachments': [{'path': 'Book/Lee_Wagenmakers_2013_Bayesian cognitive modeling.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'urn:isbn:978-0-12-405888-0',
#   'title': 'Doing Bayesian data analysis: a tutorial with R, JAGS, and Stan',
#   'attachments': [{'path': 'Book/Kruschke_2015_Doing Bayesian data analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'http://www.mitpressjournals.org/doi/10.1162/neco.2007.19.12.3335',
#   'title': 'Bayesian Inference Explains Perception of Unity and Ventriloquism Aftereffect: Identification of Common Sources of Audiovisual Stimuli',
#   'attachments': [{'path': 'Journal Article/Sato et al_2007_Bayesian Inference Explains Perception of Unity and Ventriloquism Aftereffect.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'http://www.nature.com/articles/s41467-019-12170-0',
#   'title': 'A Bayesian psychophysics model of sense of agency',
#   'attachments': [{'path': 'Journal Article/Legaspi_Toyoizumi_2019_A Bayesian psychophysics model of sense of agency.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry',
#    '🖥️Computational Psychiatry/Model-based',
#    '🖥️Computational Psychiatry/Model-based/Bayesian Inference'}},
#  {'id': 'urn:isbn:978-0-08-048932-2',
#   'title': 'Knowledge Representation and Reasoning.',
#   'attachments': [{'path': 'Book/Brachman_Levesque_2004_Knowledge representation and reasoning.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry'}},
#  {'id': 'urn:isbn:978-0-262-04199-7',
#   'title': 'Theoretical neuroscience: computational and mathematical modeling of neural systems',
#   'attachments': [{'path': 'Book/Dayan_Abbott_2001_Theoretical neuroscience.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🧠Basic Neuroscience'}},
#  {'id': 'https://ci.nii.ac.jp/naid/120005945509/',
#   'title': '心理療法の作用機序',
#   'attachments': [{'path': 'Journal Article/池田_高橋_2007_心理療法の作用機序.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🏥Clinical Psychiatry'}},
#  {'id': 'https://ci.nii.ac.jp/naid/40021232591/',
#   'title': '伝統的精神医学の理念型とプロトタイプ診断(Westen D) (特集 精神病理学の新課題 : スペクトラムと臨床診断単位の認識論・存在論)',
#   'attachments': [{'path': 'Journal Article/古茶_2017_伝統的精神医学の理念型とプロトタイプ診断(Westen D) (特集 精神病理学の新課題.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🏥Clinical Psychiatry'}},
#  {'id': 'http://www.nature.com/articles/s41380-019-0553-7',
#   'title': 'White matter microstructural alterations across four major psychiatric disorders: mega-analysis study in 2937 individuals',
#   'attachments': [{'path': 'Journal Article/COCORO et al_2020_White matter microstructural alterations across four major psychiatric disorders.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/diffusion'}},
#  {'id': 'urn:isbn:978-4-563-00870-3',
#   'title': '統計学演習',
#   'attachments': [{'path': 'Book/村上正康_安田正実_1989_統計学演習.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S105381191600210X',
#   'title': 'Single subject prediction of brain disorders in neuroimaging: Promises and pitfalls',
#   'attachments': [{'path': 'Journal Article/Arbabshirani et al_2017_Single subject prediction of brain disorders in neuroimaging.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Machine Learning'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811916302877',
#   'title': 'Computational neuroimaging strategies for single patient predictions',
#   'attachments': [{'path': 'Journal Article/Stephan et al_2017_Computational neuroimaging strategies for single patient predictions.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Machine Learning'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811916001506',
#   'title': 'HYDRA: Revealing heterogeneity of imaging and genetic patterns through a multiple max-margin discriminative analysis framework',
#   'attachments': [{'path': 'Journal Article/Varol et al_2017_HYDRA.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure'}},
#  {'id': 'urn:isbn:978-0-387-84857-0%20978-0-387-84858-7',
#   'title': 'The Elements of Statistical Learning',
#   'attachments': [{'path': 'Book/Hastie et al_2009_The Elements of Statistical Learning.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'https://academic.oup.com/ije/article/48/5/1414/5382248',
#   'title': 'Cohort Profile: The Tokyo Teen Cohort study (TTC)',
#   'attachments': [{'path': 'Journal Article/Ando et al_2019_Cohort Profile.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'TTC'}},
#  {'id': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/pcn.12814',
#   'title': 'Population‐neuroscience study of the Tokyo TEEN Cohort (pn‐TTC): Cohort longitudinal study to explore the neurobiological substrates of adolescent psychological and behavioral development',
#   'attachments': [{'path': 'Journal Article/Okada et al_2019_Population‐neuroscience study of the Tokyo TEEN Cohort (pn‐TTC).pdf',
#     'type': 'application/pdf'}],
#   'tags': {'TTC'}},
#  {'id': '#item_137',
#   'title': 'Abnormal asymmetries in subcortical brain volume in schizophrenia',
#   'attachments': [{'path': 'Journal Article/Okada et al_2016_Abnormal asymmetries in subcortical brain volume in schizophrenia2.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811919310699',
#   'title': 'Smaller anterior subgenual cingulate volume mediates the effect of girls’ early sexual maturation on negative psychobehavioral outcome',
#   'attachments': [{'path': 'Journal Article/Okada et al_2020_Smaller anterior subgenual cingulate volume mediates the effect of girls’ early.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure', 'TTC'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1878929314000310',
#   'title': 'Methods and considerations for longitudinal structural brain imaging analysis across development',
#   'attachments': [{'path': 'Journal Article/Mills_Tamnes_2014_Methods and considerations for longitudinal structural brain imaging analysis.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'MRI', 'MRI/structure'}},
#  {'id': 'https://www.cambridge.org/core/product/identifier/S0033291718000430/type/journal_article',
#   'title': 'What is mood? A computational perspective',
#   'attachments': [{'path': 'Journal Article/Clark et al_2018_What is mood.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry'}},
#  {'id': 'urn:isbn:978-1-4614-7137-0',
#   'title': 'An introduction to statistical learning: with applications in R',
#   'attachments': [{'path': 'Book/James et al_2013_An introduction to statistical learning.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'urn:isbn:978-1-4665-8696-3',
#   'title': 'Advanced R',
#   'attachments': [{'path': 'Book/Wickham_2015_Advanced R.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'urn:isbn:978-0-262-01802-9',
#   'title': 'Machine learning: a probabilistic perspective',
#   'attachments': [{'path': 'Book/Murphy_2012_Machine learning.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Machine Learning'}},
#  {'id': 'https://ci.nii.ac.jp/naid/40020960086/en/',
#   'title': '知的障害者の「責任能力」に関する一考察 : 最決平成27年3月3日LEX/DB25506282を契機として',
#   'attachments': [{'path': 'Journal Article/田川_2015_知的障害者の「責任能力」に関する一考察.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'⚖️Forensic Psychiatry'}},
#  {'id': 'urn:isbn:978-1-4614-6226-2%20978-1-4614-6227-9',
#   'title': 'Understanding Statistics Using R',
#   'attachments': [{'path': 'Book/Schumacker_Tomek_2013_Understanding Statistics Using R.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Statistics'}},
#  {'id': 'https://www.jstage.jst.go.jp/article/jnns/22/1/22_30/_article/-char/ja/',
#   'title': 'Changing Concepts of Decision',
#   'attachments': [{'path': 'Journal Article/Akaishi_2015_Changing Concepts of Decision.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry'}},
#  {'id': 'http://ci.nii.ac.jp/naid//40020309870',
#   'title': 'うつとストレスに対する計算論的アプローチ : 計算論的精神医学入門 (第28回日本ストレス学会学術総会記録) – (ストレスと認知機能)',
#   'attachments': [{'path': 'Journal Article/国里_2013_うつとストレスに対する計算論的アプローチ.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'🖥️Computational Psychiatry'}},
#  {'id': '#item_148',
#   'title': '計算論的精神医学：脳の数理モデルを用いて精神疾患の病態に迫る',
#   'attachments': [{'path': 'Journal Article/祐一_2019_計算論的精神医学：脳の数理モデルを用いて精神疾患の病態に迫る.pdf',
#     'type': 'application/pdf'}],
# ...
#   'attachments': [{'path': 'Journal Article/Milasauskiene et al_2021_Compulsive Internet Use Scale.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://www.frontiersin.org/articles/10.3389/fpsyt.2021.679437/full',
#   'title': 'Structural and Functional Brain Abnormalities in Internet Gaming Disorder and Attention-Deficit/Hyperactivity Disorder: A Comparative Meta-Analysis',
#   'attachments': [{'path': 'Journal Article/Gao et al_2021_Structural and Functional Brain Abnormalities in Internet Gaming Disorder and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://link.springer.com/10.1007/s00787-021-01808-4',
#   'title': 'Bidirectional relationship of problematic Internet use with hyperactivity/inattention and depressive symptoms in adolescents: a population-based cohort study',
#   'attachments': [{'path': 'Journal Article/Morita et al_2022_Bidirectional relationship of problematic Internet use with.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU', 'TTC'}},
#  {'id': 'https://www.tandfonline.com/doi/full/10.31887/DCNS.2020.22.2/aweinstein',
#   'title': 'Neurobiological mechanisms underlying internet gaming disorder',
#   'attachments': [{'path': 'Journal Article/Weinstein_Lejoyeux_2020_Neurobiological mechanisms underlying internet gaming disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0031395519301166',
#   'title': 'Behavioral Addictions',
#   'attachments': [{'path': 'Journal Article/Derevensky et al_2019_Behavioral Addictions.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://www.frontiersin.org/article/10.3389/fnhum.2018.00493/full',
#   'title': 'Neural Correlates of Non-clinical Internet Use in the Motivation Network and Its Modulation by Subclinical Autistic Traits',
#   'attachments': [{'path': 'Journal Article/Fujiwara et al_2018_Neural Correlates of Non-clinical Internet Use in the Motivation Network and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'http://journal.frontiersin.org/article/10.3389/fpsyt.2018.00077/full',
#   'title': 'Altered Gray Matter Volume and Resting-State Connectivity in Individuals With Internet Gaming Disorder: A Voxel-Based Morphometry and Resting-State Functional Magnetic Resonance Imaging Study',
#   'attachments': [{'path': 'Journal Article/Seok_Sohn_2018_Altered Gray Matter Volume and Resting-State Connectivity in Individuals With.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2352853216300438',
#   'title': 'Internet use and problematic Internet use among adolescents in Japan: A nationwide representative survey',
#   'attachments': [{'path': 'Journal Article/Mihara et al_2016_Internet use and problematic Internet use among adolescents in Japan.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763417305870',
#   'title': 'Functional and structural neural alterations in Internet gaming disorder: A systematic review and meta-analysis',
#   'attachments': [{'path': 'Journal Article/Yao et al_2017_Functional and structural neural alterations in Internet gaming disorder.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'http://www.wjgnet.com/2220-3206/full/v6/i1/143.htm',
#   'title': 'Internet addiction and problematic Internet use: A systematic review of clinical research',
#   'attachments': [{'path': 'Journal Article/Kuss_Lopez-Fernandez_2016_Internet addiction and problematic Internet use.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'http://link.springer.com/10.1007/s11682-015-9454-9',
#   'title': 'Problematic internet use is associated with structural alterations in the brain reward system in females',
#   'attachments': [{'path': 'Journal Article/Altbacker et al_2016_Problematic internet use is associated with structural alterations in the brain.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'http://www.liebertpub.com/doi/10.1089/cyber.2014.0475',
#   'title': 'Problematic Internet Use and Problematic Online Gaming Are Not the Same: Findings from a Large Nationally Representative Adolescent Sample',
#   'attachments': [{'path': 'Journal Article/Kiraly et al_2014_Problematic Internet Use and Problematic Online Gaming Are Not the Same.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'http://link.springer.com/10.1007/s11920-014-0508-2',
#   'title': 'Risk Factors of Internet Addiction and the Health Effect of Internet Addiction on Adolescents: A Systematic Review of Longitudinal and Prospective Studies',
#   'attachments': [{'path': 'Journal Article/Lam_2014_Risk Factors of Internet Addiction and the Health Effect of Internet Addiction.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://www.karger.com/Article/FullText/355076',
#   'title': 'Assessment of Problematic Internet Use by the Compulsive Internet Use Scale and the Internet Addiction Test: A Sample of Problematic and Pathological Gamblers',
#   'attachments': [{'path': 'Journal Article/Guertler et al_2014_Assessment of Problematic Internet Use by the Compulsive Internet Use Scale and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC PIU'}},
#  {'id': 'https://journals.lww.com/10.1097/YCO.0000000000000663',
#   'title': 'Measuring resilience in children: a review of recent literature and recommendations for future research',
#   'attachments': [{'path': 'Journal Article/King et al_2021_Measuring resilience in children.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'http://journals.sagepub.com/doi/10.1177/1754073918768878',
#   'title': 'Understanding Emotion in Adolescents: A Review of Emotional Frequency, Intensity, Instability, and Clarity',
#   'attachments': [{'path': 'Journal Article/Bailen et al_2019_Understanding Emotion in Adolescents.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://www.frontiersin.org/articles/10.3389/fpsyt.2022.865907/full',
#   'title': 'Being Praised for Prosocial Behaviors Longitudinally Reduces Depressive Symptoms in Early Adolescents: A Population-Based Cohort Study',
#   'attachments': [{'path': 'Journal Article/Nagaoka et al_2022_Being Praised for Prosocial Behaviors Longitudinally Reduces Depressive.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T', 'TTC'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S2451902221002858',
#   'title': 'Examining Associations Between Amygdala Volumes and Anxiety Symptoms in Autism Spectrum Disorder',
#   'attachments': [{'path': 'Journal Article/Yarger et al_2022_Examining Associations Between Amygdala Volumes and Anxiety Symptoms in Autism.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://www.nature.com/articles/s41467-021-23994-0',
#   'title': 'Brain structure is linked to the association between family environment and behavioral problems in children in the ABCD study',
#   'attachments': [{'path': 'Journal Article/Gong et al_2021_Brain structure is linked to the association between family environment and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://www.nature.com/articles/s41380-021-01161-7',
#   'title': 'Age at onset of mental disorders worldwide: large-scale meta-analysis of 192 epidemiological studies',
#   'attachments': [{'path': 'Journal Article/Solmi et al_2022_Age at onset of mental disorders worldwide.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0006322320318126',
#   'title': 'Negative Parenting Affects Adolescent Internalizing Symptoms Through Alterations in Amygdala-Prefrontal Circuitry: A Longitudinal Twin Study',
#   'attachments': [{'path': 'Journal Article/Jiang et al_2021_Negative Parenting Affects Adolescent Internalizing Symptoms Through.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0890856720300186',
#   'title': 'High Psychopathology Subgroup in Young Children With Autism: Associations With Biological Sex and Amygdala Volume',
#   'attachments': [{'path': 'Journal Article/Nordahl et al_2020_High Psychopathology Subgroup in Young Children With Autism.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://dx.plos.org/10.1371/journal.pone.0225088',
#   'title': 'Unique developmental trajectories of risk behaviors in adolescence and associated outcomes in young adulthood',
#   'attachments': [{'path': 'Journal Article/Peeters et al_2019_Unique developmental trajectories of risk behaviors in adolescence and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'http://ajp.psychiatryonline.org/doi/10.1176/appi.ajp.2019.19010091',
#   'title': 'Translating Developmental Neuroscience to Understand Risk for Psychiatric Disorders',
#   'attachments': [{'path': 'Journal Article/Meyer_Lee_2019_Translating Developmental Neuroscience to Understand Risk for Psychiatric.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0925492717301439',
#   'title': 'Amygdala volume mediates the relationship between externalizing symptoms and daily smoking in adolescence: A prospective study',
#   'attachments': [{'path': 'Journal Article/Cheetham et al_2018_Amygdala volume mediates the relationship between externalizing symptoms and.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://www.tandfonline.com/doi/full/10.1080/15374416.2017.1326122',
#   'title': 'Socioeconomic Status, Amygdala Volume, and Internalizing Symptoms in Children and Adolescents',
#   'attachments': [{'path': 'Journal Article/Merz et al_2018_Socioeconomic Status, Amygdala Volume, and Internalizing Symptoms in Children.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0301051117300297',
#   'title': 'Age-related volumetric change of limbic structures and subclinical anxious/depressed symptomatology in typically developing children and adolescents',
#   'attachments': [{'path': 'Journal Article/Albaugh et al_2017_Age-related volumetric change of limbic structures and subclinical.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763416301609',
#   'title': 'The neurobiology of the emotional adolescent: From the inside out',
#   'attachments': [{'path': 'Journal Article/Guyer et al_2016_The neurobiology of the emotional adolescent.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://pnas.org/doi/full/10.1073/pnas.1524907113',
#   'title': 'Pubertal activation of estrogen receptor α in the medial amygdala is essential for the full expression of male social behavior in mice',
#   'attachments': [{'path': 'Journal Article/Sano et al_2016_Pubertal activation of estrogen receptor α in the medial amygdala is essential.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'http://www.nature.com/articles/npp2014236',
#   'title': 'Child Psychiatry Branch of the National Institute of Mental Health Longitudinal Structural Magnetic Resonance Imaging Study of Human Brain Development',
#   'attachments': [{'path': 'Journal Article/Giedd et al_2015_Child Psychiatry Branch of the National Institute of Mental Health Longitudinal.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1054139X14002250',
#   'title': 'Testosterone and Its Effects on Human Male Adolescent Mood and Behavior: A Systematic Review',
#   'attachments': [{'path': 'Journal Article/Duke et al_2014_Testosterone and Its Effects on Human Male Adolescent Mood and Behavior.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0091302213000654',
#   'title': 'Puberty and adolescence as a time of vulnerability to stressors that alter neurobehavioral processes',
#   'attachments': [{'path': 'Journal Article/Holder_Blaustein_2014_Puberty and adolescence as a time of vulnerability to stressors that alter.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811913008720',
#   'title': 'Age-related changes in the structure and function of prefrontal cortex–amygdala circuitry in children and adolescents: A multi-modal imaging approach',
#   'attachments': [{'path': 'Journal Article/Swartz et al_2014_Age-related changes in the structure and function of prefrontal cortex–amygdala.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0018506X13001219',
#   'title': 'The amygdala: An agent of change in adolescent neural networks',
#   'attachments': [{'path': 'Journal Article/Scherf et al_2013_The amygdala.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'http://www.nature.com/articles/nn.3257',
#   'title': 'Developmental pathways to amygdala-prefrontal function and internalizing symptoms in adolescence',
#   'attachments': [{'path': 'Journal Article/Burghy et al_2012_Developmental pathways to amygdala-prefrontal function and internalizing.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0959438807000414',
#   'title': 'Emotional and cognitive changes during adolescence',
#   'attachments': [{'path': 'Journal Article/Yurgelun-Todd_2007_Emotional and cognitive changes during adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://www.cambridge.org/core/product/identifier/S0954579400003102/type/journal_article',
#   'title': 'Internalizing problems of childhood and adolescence: Prospects, pitfalls, and progress inunderstanding the development of anxiety and depression',
#   'attachments': [{'path': 'Journal Article/Zahn–Waxler et al_2000_Internalizing problems of childhood and adolescence.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763400000142',
#   'title': 'The adolescent brain and age-related behavioral manifestations',
#   'attachments': [{'path': 'Journal Article/Spear_2000_The adolescent brain and age-related behavioral manifestations.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'!📄Paper:(2023)pnTTC CBCL Amyg T'}},
#  {'id': 'http://arxiv.org/abs/2207.09238',
#   'title': 'Formal Algorithms for Transformers',
#   'attachments': [{'path': 'Preprint/Phuong_Hutter_2022_Formal Algorithms for Transformers.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Machine Learning', 'Machine Learning/Transformer'}},
#  {'id': '#item_506',
#   'title': 'Attention is All you Need',
#   'attachments': [{'path': 'Journal Article/Vaswani et al_Attention is All you Need.pdf',
#     'type': 'application/pdf'}],
#   'tags': {'Machine Learning', 'Machine Learning/Transformer'}}]

# %%
def parse_csl_jsonlib_json
# Out:
# [{'id': 'XinJingKarubonirusutoresuDaiXieZhangHaitoTongHeShiDiaoZheng2015',
#   'type': 'article-journal',
#   'container-title': '日本生物学的精神医学会誌',
#   'DOI': '10.11249/jsbpjjpp.26.1_27',
#   'issue': '1',
#   'journalAbbreviation': '日本生物学的精神医学会誌',
#   'page': '27-33',
#   'title': 'カルボニルストレス代謝障害と統合失調症',
#   'volume': '26',
#   'author': [{'family': '新井', 'given': '誠'},
#    {'family': '小堀', 'given': '晶子'},
#    {'family': '宮下', 'given': '光弘'},
#    {'family': '鳥海', 'given': '和也'},
#    {'family': '堀内', 'given': '泰江'},
#    {'family': '畠山', 'given': '幸子'},
#    {'family': '内田', 'given': '美樹'},
#    {'family': '井上', 'given': '智子'},
#    {'family': '糸川', 'given': '昌成'}],
#   'issued': {'date-parts': [['2015']]}},
#  {'id': 'YuShiXinLiXueniokerubeizuTongJimoderingu2018',
#   'type': 'article-journal',
#   'container-title': '心理学評論',
#   'DOI': '10.24602/sjpr.61.1_22',
#   'issue': '1',
#   'page': '22-41',
#   'title': '心理学におけるベイズ統計モデリング',
#   'volume': '61',
#   'author': [{'family': '裕士', 'given': '清水'}],
#   'issued': {'date-parts': [['2018']]}},
#  {'id': 'okadaNeurometabolicFunctionalConnectivity2019',
#   'type': 'article-journal',
#   'container-title': 'Scientific Reports',
#   'DOI': '10.1038/s41598-018-38355-z',
#   'ISSN': '2045-2322',
#   'issue': '1',
#   'journalAbbreviation': 'Sci Rep',
#   'language': 'en',
#   'note': 'PMID: 30679738',
#   'page': '732',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Neurometabolic and functional connectivity basis of prosocial behavior in early adolescence',
#   'URL': 'http://www.nature.com/articles/s41598-018-38355-z',
#   'volume': '9',
#   'author': [{'family': 'Okada', 'given': 'Naohiro'},
#    {'family': 'Yahata', 'given': 'Noriaki'},
#    {'family': 'Koshiyama', 'given': 'Daisuke'},
#    {'family': 'Morita', 'given': 'Kentaro'},
#    {'family': 'Sawada', 'given': 'Kingo'},
#    {'family': 'Kanata', 'given': 'Sho'},
#    {'family': 'Fujikawa', 'given': 'Shinya'},
#    {'family': 'Sugimoto', 'given': 'Noriko'},
#    {'family': 'Toriyama', 'given': 'Rie'},
#    {'family': 'Masaoka', 'given': 'Mio'},
#    {'family': 'Koike', 'given': 'Shinsuke'},
#    {'family': 'Araki', 'given': 'Tsuyoshi'},
#    {'family': 'Kano', 'given': 'Yukiko'},
#    {'family': 'Endo', 'given': 'Kaori'},
#    {'family': 'Yamasaki', 'given': 'Syudo'},
#    {'family': 'Ando', 'given': 'Shuntaro'},
#    {'family': 'Nishida', 'given': 'Atsushi'},
#    {'family': 'Hiraiwa-Hasegawa', 'given': 'Mariko'},
#    {'family': 'Edden', 'given': 'Richard A. E.'},
#    {'family': 'Barker', 'given': 'Peter B.'},
#    {'family': 'Sawa', 'given': 'Akira'},
#    {'family': 'Kasai', 'given': 'Kiyoto'}],
#   'accessed': {'date-parts': [['2022', 3, 31]]},
#   'issued': {'date-parts': [['2019', 12]]}},
#  {'id': 'liaoPubertalTestosteroneStructure2021',
#   'type': 'article-journal',
#   'abstract': 'Adolescence is a period of brain maturation that may involve a second wave of organizational effects of sex steroids on the brain. Rodent studies suggest that, overall, organizational effects of gonadal steroid hormones decrease from the prenatal/perinatal period to adulthood. Here we used multimodal magnetic resonance imaging to investigate whether 1) testosterone exposure during adolescence (9–17 years) correlates with the structure of cerebral cortex in young men (n = 216, 19 years of age); 2) this relationship is modulated by the timing of testosterone surge during puberty. Our results showed that pubertal testosterone correlates with structural properties of the cerebral cortex, as captured by principal component analysis of T1 and T2 relaxation times, myelin water fraction, magnetization transfer ratio, fractional anisotropy and mean diffusivity. Many of the correlations between pubertal testosterone and the cortical structure were stronger in individuals with earlier (vs. later) testosterone surge. We also demonstrated that the strength of the relationship between pubertal testosterone and cortical structure across the cerebral cortex varies as a function of inter-regional profiles of gene expression specific to dendrites, axonal cytoskeleton, and myelin. This finding suggests that the cellular substrate underlying the relationships between pubertal testosterone and cerebral cortex involves both dendritic arbor and axon.',
#   'container-title': 'Cerebral Cortex',
#   'DOI': '10.1093/cercor/bhaa389',
#   'ISSN': '1047-3211, 1460-2199',
#   'issue': '6',
#   'journalAbbreviation': 'Cereb. Cortex',
#   'language': 'en',
#   'note': 'PMID: 33429422',
#   'page': '2812-2821',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Pubertal Testosterone and the Structure of the Cerebral Cortex in Young Men',
#   'URL': 'https://academic.oup.com/cercor/article/31/6/2812/6082824',
#   'volume': '31',
#   'author': [{'family': 'Liao', 'given': 'Zhijie'},
#    {'family': 'Patel', 'given': 'Yash'},
#    {'family': 'Khairullah', 'given': 'Ammar'},
#    {'family': 'Parker', 'given': 'Nadine'},
#    {'family': 'Paus', 'given': 'Tomas'}],
#   'accessed': {'date-parts': [['2021', 10, 6]]},
#   'issued': {'date-parts': [['2021', 5, 10]]}},
#  {'id': 'khairullahTestosteroneTrajectoriesReference2014',
#   'type': 'article-journal',
#   'abstract': 'Purpose: Pubertal dynamics plays an important role in physical and psychological development of children and adolescents. We aim to provide reference ranges of plasma testosterone in a large longitudinal sample. Furthermore, we describe a measure of testosterone trajectories during adolescence that can be used in future investigations of development.\nMethods: We carried out longitudinal measurements of plasma testosterone in 2,216 samples obtained from 513 males (9 to 17 years of age) from the Avon Longitudinal Study of Parents and Children. We used integration of a model fitted to each participant’s testosterone trajectory to calculate a measure of average exposure to testosterone over adolescence. We pooled these data with corresponding values reported in the literature to provide a reference range of testosterone levels in males between the ages of 6 and 19 years.\nResults: The average values of total testosterone in the ALSPAC sample range from 0.82 nmol/L (Standard Deviation [SD]: 0.09) at 9 years of age to 16.5 (SD: 2.65) nmol/L at 17 years of age; these values are congruent with other reports in the literature. The average exposure to testosterone is associated with different features of testosterone trajectories such as Peak Testosterone Change, Age at Peak Testosterone Change, and Testosterone at 17 years of age as well as the timing of the growth spurt during puberty.\nConclusions: The average exposure to testosterone is a useful measure for future investigations using testosterone trajectories to examine pubertal dynamics.',
#   'container-title': 'PLoS ONE',
#   'DOI': '10.1371/journal.pone.0108838',
#   'ISSN': '1932-6203',
#   'issue': '9',
#   'journalAbbreviation': 'PLoS ONE',
#   'language': 'en',
#   'note': 'PMID: 25268961',
#   'page': 'e108838',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Testosterone Trajectories and Reference Ranges in a Large Longitudinal Sample of Male Adolescents',
#   'URL': 'https://dx.plos.org/10.1371/journal.pone.0108838',
#   'volume': '9',
#   'author': [{'family': 'Khairullah', 'given': 'Ammar'},
#    {'family': 'Cousino Klein', 'given': 'Laura'},
#    {'family': 'Ingle', 'given': 'Suzanne M.'},
#    {'family': 'May', 'given': 'Margaret T.'},
#    {'family': 'Whetzel', 'given': 'Courtney A.'},
#    {'family': 'Susman', 'given': 'Elizabeth J.'},
#    {'family': 'Paus', 'given': 'Tomáš'}],
#   'editor': [{'family': 'McCormick', 'given': 'Cheryl'}],
#   'accessed': {'date-parts': [['2022', 2, 24]]},
#   'issued': {'date-parts': [['2014', 9, 30]]}},
#  {'id': 'guadalupeHumanSubcorticalBrain2017',
#   'type': 'article-journal',
#   'container-title': 'Brain Imaging and Behavior',
#   'DOI': '10.1007/s11682-016-9629-z',
#   'ISSN': '1931-7557, 1931-7565',
#   'issue': '5',
#   'journalAbbreviation': 'Brain Imaging and Behavior',
#   'language': 'en',
#   'note': 'PMID: 27738994',
#   'page': '1497-1514',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Human subcortical brain asymmetries in 15,847 people worldwide reveal effects of age and sex',
#   'URL': 'http://link.springer.com/10.1007/s11682-016-9629-z',
#   'volume': '11',
#   'author': [{'family': 'Guadalupe', 'given': 'Tulio'},
#    {'family': 'Mathias', 'given': 'Samuel R.'},
#    {'family': 'vanErp', 'given': 'Theo G. M.'},
#    {'family': 'Whelan', 'given': 'Christopher D.'},
#    {'family': 'Zwiers', 'given': 'Marcel P.'},
#    {'family': 'Abe', 'given': 'Yoshinari'},
#    {'family': 'Abramovic', 'given': 'Lucija'},
#    {'family': 'Agartz', 'given': 'Ingrid'},
#    {'family': 'Andreassen', 'given': 'Ole A.'},
#    {'family': 'Arias-Vásquez', 'given': 'Alejandro'},
#    {'family': 'Aribisala', 'given': 'Benjamin S.'},
#    {'family': 'Armstrong', 'given': 'Nicola J.'},
#    {'family': 'Arolt', 'given': 'Volker'},
#    {'family': 'Artiges', 'given': 'Eric'},
#    {'family': 'Ayesa-Arriola', 'given': 'Rosa'},
#    {'family': 'Baboyan', 'given': 'Vatche G.'},
#    {'family': 'Banaschewski', 'given': 'Tobias'},
#    {'family': 'Barker', 'given': 'Gareth'},
#    {'family': 'Bastin', 'given': 'Mark E.'},
#    {'family': 'Baune', 'given': 'Bernhard T.'},
#    {'family': 'Blangero', 'given': 'John'},
#    {'family': 'Bokde', 'given': 'Arun L.W.'},
#    {'family': 'Boedhoe', 'given': 'Premika S.W.'},
#    {'family': 'Bose', 'given': 'Anushree'},
#    {'family': 'Brem', 'given': 'Silvia'},
#    {'family': 'Brodaty', 'given': 'Henry'},
#    {'family': 'Bromberg', 'given': 'Uli'},
#    {'family': 'Brooks', 'given': 'Samantha'},
#    {'family': 'Büchel', 'given': 'Christian'},
#    {'family': 'Buitelaar', 'given': 'Jan'},
#    {'family': 'Calhoun', 'given': 'Vince D.'},
#    {'family': 'Cannon', 'given': 'Dara M.'},
#    {'family': 'Cattrell', 'given': 'Anna'},
#    {'family': 'Cheng', 'given': 'Yuqi'},
#    {'family': 'Conrod', 'given': 'Patricia J.'},
#    {'family': 'Conzelmann', 'given': 'Annette'},
#    {'family': 'Corvin', 'given': 'Aiden'},
#    {'family': 'Crespo-Facorro', 'given': 'Benedicto'},
#    {'family': 'Crivello', 'given': 'Fabrice'},
#    {'family': 'Dannlowski', 'given': 'Udo'},
#    {'family': 'Zubicaray', 'given': 'Greig I.', 'non-dropping-particle': 'de'},
#    {'family': 'Zwarte', 'given': 'Sonja M.C.', 'non-dropping-particle': 'de'},
#    {'family': 'Deary', 'given': 'Ian J.'},
#    {'family': 'Desrivières', 'given': 'Sylvane'},
#    {'family': 'Doan', 'given': 'Nhat Trung'},
#    {'family': 'Donohoe', 'given': 'Gary'},
#    {'family': 'Dørum', 'given': 'Erlend S.'},
#    {'family': 'Ehrlich', 'given': 'Stefan'},
#    {'family': 'Espeseth', 'given': 'Thomas'},
#    {'family': 'Fernández', 'given': 'Guillén'},
#    {'family': 'Flor', 'given': 'Herta'},
#    {'family': 'Fouche', 'given': 'Jean-Paul'},
#    {'family': 'Frouin', 'given': 'Vincent'},
#    {'family': 'Fukunaga', 'given': 'Masaki'},
#    {'family': 'Gallinat', 'given': 'Jürgen'},
#    {'family': 'Garavan', 'given': 'Hugh'},
#    {'family': 'Gill', 'given': 'Michael'},
#    {'family': 'Suarez', 'given': 'Andrea Gonzalez'},
#    {'family': 'Gowland', 'given': 'Penny'},
#    {'family': 'Grabe', 'given': 'Hans J.'},
#    {'family': 'Grotegerd', 'given': 'Dominik'},
#    {'family': 'Gruber', 'given': 'Oliver'},
#    {'family': 'Hagenaars', 'given': 'Saskia'},
#    {'family': 'Hashimoto', 'given': 'Ryota'},
#    {'family': 'Hauser', 'given': 'Tobias U.'},
#    {'family': 'Heinz', 'given': 'Andreas'},
#    {'family': 'Hibar', 'given': 'Derrek P.'},
#    {'family': 'Hoekstra', 'given': 'Pieter J.'},
#    {'family': 'Hoogman', 'given': 'Martine'},
#    {'family': 'Howells', 'given': 'Fleur M.'},
#    {'family': 'Hu', 'given': 'Hao'},
#    {'family': 'Hulshoff Pol', 'given': 'Hilleke E.'},
#    {'family': 'Huyser', 'given': 'Chaim'},
#    {'family': 'Ittermann', 'given': 'Bernd'},
#    {'family': 'Jahanshad', 'given': 'Neda'},
#    {'family': 'Jönsson', 'given': 'Erik G.'},
#    {'family': 'Jurk', 'given': 'Sarah'},
#    {'family': 'Kahn', 'given': 'Rene S.'},
#    {'family': 'Kelly', 'given': 'Sinead'},
#    {'family': 'Kraemer', 'given': 'Bernd'},
#    {'family': 'Kugel', 'given': 'Harald'},
#    {'family': 'Kwon', 'given': 'Jun Soo'},
#    {'family': 'Lemaitre', 'given': 'Herve'},
#    {'family': 'Lesch', 'given': 'Klaus-Peter'},
#    {'family': 'Lochner', 'given': 'Christine'},
#    {'family': 'Luciano', 'given': 'Michelle'},
#    {'family': 'Marquand', 'given': 'Andre F.'},
#    {'family': 'Martin', 'given': 'Nicholas G.'},
#    {'family': 'Martínez-Zalacaín', 'given': 'Ignacio'},
#    {'family': 'Martinot', 'given': 'Jean-Luc'},
#    {'family': 'Mataix-Cols', 'given': 'David'},
#    {'family': 'Mather', 'given': 'Karen'},
#    {'family': 'McDonald', 'given': 'Colm'},
#    {'family': 'McMahon', 'given': 'Katie L.'},
#    {'family': 'Medland', 'given': 'Sarah E.'},
#    {'family': 'Menchón', 'given': 'José M.'},
#    {'family': 'Morris', 'given': 'Derek W.'},
#    {'family': 'Mothersill', 'given': 'Omar'},
#    {'family': 'Maniega', 'given': 'Susana Munoz'},
#    {'family': 'Mwangi', 'given': 'Benson'},
#    {'family': 'Nakamae', 'given': 'Takashi'},
#    {'family': 'Nakao', 'given': 'Tomohiro'},
#    {'family': 'Narayanaswaamy', 'given': 'Janardhanan C.'},
#    {'family': 'Nees', 'given': 'Frauke'},
#    {'family': 'Nordvik', 'given': 'Jan E.'},
#    {'family': 'Onnink', 'given': 'A. Marten H.'},
#    {'family': 'Opel', 'given': 'Nils'},
#    {'family': 'Ophoff', 'given': 'Roel'},
#    {'family': 'Paillère Martinot', 'given': 'Marie-Laure'},
#    {'family': 'Papadopoulos Orfanos', 'given': 'Dimitri'},
#    {'family': 'Pauli', 'given': 'Paul'},
#    {'family': 'Paus', 'given': 'Tomáš'},
#    {'family': 'Poustka', 'given': 'Luise'},
#    {'family': 'Reddy', 'given': 'Janardhan YC.'},
#    {'family': 'Renteria', 'given': 'Miguel E.'},
#    {'family': 'Roiz-Santiáñez', 'given': 'Roberto'},
#    {'family': 'Roos', 'given': 'Annerine'},
#    {'family': 'Royle', 'given': 'Natalie A.'},
#    {'family': 'Sachdev', 'given': 'Perminder'},
#    {'family': 'Sánchez-Juan', 'given': 'Pascual'},
#    {'family': 'Schmaal', 'given': 'Lianne'},
#    {'family': 'Schumann', 'given': 'Gunter'},
#    {'family': 'Shumskaya', 'given': 'Elena'},
#    {'family': 'Smolka', 'given': 'Michael N.'},
#    {'family': 'Soares', 'given': 'Jair C.'},
#    {'family': 'Soriano-Mas', 'given': 'Carles'},
#    {'family': 'Stein', 'given': 'Dan J.'},
#    {'family': 'Strike', 'given': 'Lachlan T.'},
#    {'family': 'Toro', 'given': 'Roberto'},
#    {'family': 'Turner', 'given': 'Jessica A.'},
#    {'family': 'Tzourio-Mazoyer', 'given': 'Nathalie'},
#    {'family': 'Uhlmann', 'given': 'Anne'},
#    {'family': 'Hernández', 'given': 'Maria Valdés'},
#    {'family': 'Heuvel',
#     'given': 'Odile A.',
#     'non-dropping-particle': 'van den'},
#    {'family': 'Meer', 'given': 'Dennis', 'non-dropping-particle': 'van der'},
#    {'family': 'Haren',
#     'given': 'Neeltje E.M .',
#     'non-dropping-particle': 'van'},
#    {'family': 'Veltman', 'given': 'Dick J.'},
#    {'family': 'Venkatasubramanian', 'given': 'Ganesan'},
#    {'family': 'Vetter', 'given': 'Nora C.'},
#    {'family': 'Vuletic', 'given': 'Daniella'},
#    {'family': 'Walitza', 'given': 'Susanne'},
#    {'family': 'Walter', 'given': 'Henrik'},
#    {'family': 'Walton', 'given': 'Esther'},
#    {'family': 'Wang', 'given': 'Zhen'},
#    {'family': 'Wardlaw', 'given': 'Joanna'},
#    {'family': 'Wen', 'given': 'Wei'},
#    {'family': 'Westlye', 'given': 'Lars T.'},
#    {'family': 'Whelan', 'given': 'Robert'},
#    {'family': 'Wittfeld', 'given': 'Katharina'},
#    {'family': 'Wolfers', 'given': 'Thomas'},
#    {'family': 'Wright', 'given': 'Margaret J.'},
#    {'family': 'Xu', 'given': 'Jian'},
#    {'family': 'Xu', 'given': 'Xiufeng'},
#    {'family': 'Yun', 'given': 'Je-Yeon'},
#    {'family': 'Zhao', 'given': 'JingJing'},
#    {'family': 'Franke', 'given': 'Barbara'},
#    {'family': 'Thompson', 'given': 'Paul M.'},
#    {'family': 'Glahn', 'given': 'David C.'},
#    {'family': 'Mazoyer', 'given': 'Bernard'},
#    {'family': 'Fisher', 'given': 'Simon E.'},
#    {'family': 'Francks', 'given': 'Clyde'}],
#   'accessed': {'date-parts': [['2022', 2, 14]]},
#   'issued': {'date-parts': [['2017', 10]]}},
#  {'id': 'guadalupeAsymmetryHumanPlanum2015',
#   'type': 'article-journal',
#   'container-title': 'Cortex',
#   'DOI': '10.1016/j.cortex.2014.07.015',
#   'ISSN': '00109452',
#   'journalAbbreviation': 'Cortex',
#   'language': 'en',
#   'note': 'PMID: 25239853',
#   'page': '41-55',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Asymmetry within and around the human planum temporale is sexually dimorphic and influenced by genes involved in steroid hormone receptor activity',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0010945214002469',
#   'volume': '62',
#   'author': [{'family': 'Guadalupe', 'given': 'Tulio'},
#    {'family': 'Zwiers', 'given': 'Marcel P.'},
#    {'family': 'Wittfeld', 'given': 'Katharina'},
#    {'family': 'Teumer', 'given': 'Alexander'},
#    {'family': 'Vasquez', 'given': 'Alejandro Arias'},
#    {'family': 'Hoogman', 'given': 'Martine'},
#    {'family': 'Hagoort', 'given': 'Peter'},
#    {'family': 'Fernandez', 'given': 'Guillen'},
#    {'family': 'Buitelaar', 'given': 'Jan'},
#    {'family': 'Bokhoven', 'given': 'Hans', 'non-dropping-particle': 'van'},
#    {'family': 'Hegenscheid', 'given': 'Katrin'},
#    {'family': 'Völzke', 'given': 'Henry'},
#    {'family': 'Franke', 'given': 'Barbara'},
#    {'family': 'Fisher', 'given': 'Simon E.'},
#    {'family': 'Grabe', 'given': 'Hans J.'},
#    {'family': 'Francks', 'given': 'Clyde'}],
#   'accessed': {'date-parts': [['2022', 2, 14]]},
#   'issued': {'date-parts': [['2015', 1]]}},
#  {'id': 'uematsuDevelopmentalTrajectoriesAmygdala2012',
#   'type': 'article-journal',
#   'abstract': 'Knowledge of amygdalar and hippocampal development as they pertain to sex differences and laterality would help to understand not only brain development but also the relationship between brain volume and brain functions. However, few studies investigated development of these two regions, especially during infancy. The purpose of this study was to examine typical volumetric trajectories of amygdala and hippocampus from infancy to early adulthood by predicting sexual dimorphism and laterality. We performed a cross-sectional morphometric MRI study of amygdalar and hippocampal growth from 1 month to 25 years old, using 109 healthy individuals. The findings indicated significant non-linear age-related volume changes, especially during the first few years of life, in both the amygdala and hippocampus regardless of sex. The peak ages of amygdalar and hippocampal volumes came at the timing of preadolescence (9–11 years old). The female amygdala reached its peak age about one year and a half earlier than the male amygdala did. In addition, its rate of growth change decreased earlier in the females. Furthermore, both females and males displayed rightward laterality in the hippocampus, but only the males in the amygdala. The robust growth of the amygdala and hippocampus during infancy highlight the importance of this period for neural and functional development. The sex differences and laterality during development of these two regions suggest that sex-related factors such as sex hormones and functional laterality might affect brain development.',
#   'container-title': 'PLoS ONE',
#   'DOI': '10.1371/journal.pone.0046970',
#   'ISSN': '1932-6203',
#   'issue': '10',
#   'journalAbbreviation': 'PLoS ONE',
#   'language': 'en',
#   'note': 'PMID: 23056545',
#   'page': 'e46970',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Developmental Trajectories of Amygdala and Hippocampus from Infancy to Early Adulthood in Healthy Individuals',
#   'URL': 'https://dx.plos.org/10.1371/journal.pone.0046970',
#   'volume': '7',
#   'author': [{'family': 'Uematsu', 'given': 'Akiko'},
#    {'family': 'Matsui', 'given': 'Mie'},
#    {'family': 'Tanaka', 'given': 'Chiaki'},
#    {'family': 'Takahashi', 'given': 'Tsutomu'},
#    {'family': 'Noguchi', 'given': 'Kyo'},
#    {'family': 'Suzuki', 'given': 'Michio'},
#    {'family': 'Nishijo', 'given': 'Hisao'}],
#   'editor': [{'family': 'Krueger', 'given': 'Frank'}],
#   'accessed': {'date-parts': [['2022', 2, 14]]},
#   'issued': {'date-parts': [['2012', 10, 9]]}},
#  {'id': 'glezermanYesThereFemale2016',
#   'type': 'article-journal',
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'DOI': '10.1073/pnas.1524418113',
#   'ISSN': '0027-8424, 1091-6490',
#   'issue': '14',
#   'journalAbbreviation': 'Proc Natl Acad Sci USA',
#   'language': 'en',
#   'note': 'PMID: 26957594\nPMCID: PMC4833230',
#   'page': 'E1971-E1971',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Yes, there is a female and a male brain: Morphology versus functionality',
#   'title-short': 'Yes, there is a female and a male brain',
#   'URL': 'http://www.pnas.org/lookup/doi/10.1073/pnas.1524418113',
#   'volume': '113',
#   'author': [{'family': 'Glezerman', 'given': 'Marek'}],
#   'accessed': {'date-parts': [['2022', 1, 26]]},
#   'issued': {'date-parts': [['2016', 4, 5]]}},
#  {'id': 'heanyQuantitativeQualitativeReview2016',
#   'type': 'article-journal',
#   'container-title': 'Metabolic Brain Disease',
#   'DOI': '10.1007/s11011-015-9692-y',
#   'ISSN': '0885-7490, 1573-7365',
#   'issue': '1',
#   'journalAbbreviation': 'Metab Brain Dis',
#   'language': 'en',
#   'note': 'PMID: 26073231',
#   'page': '157-167',
#   'source': 'DOI.org (Crossref)',
#   'title': 'A quantitative and qualitative review of the effects of testosterone on the function and structure of the human social-emotional brain',
#   'URL': 'http://link.springer.com/10.1007/s11011-015-9692-y',
#   'volume': '31',
#   'author': [{'family': 'Heany', 'given': 'Sarah J.'},
#    {'family': 'Honk', 'given': 'Jack', 'non-dropping-particle': 'van'},
#    {'family': 'Stein', 'given': 'Dan J.'},
#    {'family': 'Brooks', 'given': 'Samantha J.'}],
#   'accessed': {'date-parts': [['2022', 1, 26]]},
#   'issued': {'date-parts': [['2016', 2]]}},
#  {'id': 'roddyAmygdalaSubstructureVolumes2021',
#   'type': 'article-journal',
#   'abstract': 'The role of the amygdala in the experience of emotional states and stress is well established. Connections from the amygdala to the hypothalamus activate the hypothalamic–pituitaryadrenal (HPA) axis and the cortisol response. Previous studies have failed to find consistent whole amygdala volume changes in Major Depressive Disorder (MDD), but differences may exist at the smaller substructural level of the amygdala nuclei. Highresolution T1 and T2-weighted-fluid-attenuated inversion recovery MRIs were compared between 80 patients with MDD and 83 healthy controls (HC) using the automated amygdala substructure module in FreeSurfer 6.0. Volumetric assessments were performed for individual nuclei and three anatomico-functional composite groups of nuclei. Salivary cortisol awakening response (CAR), as a measure of HPA responsivity, was measured in a subset of patients. The right medial nucleus volume was larger in MDD compared to HC (p = 0.002). Increased right-left volume ratios were found in MDD for the whole amygdala (p = 0.004), the laterobasal composite (p = 0.009) and in the central (p = 0.003) and medial (p = 0.014) nuclei. The CAR was not significantly different between MDD and HC. Within the MDD group the left corticoamygdaloid transition area was inversely correlated with the CAR, as measured by area under the curve (AUCg) (p ≤ 0.0001). In conclusion, our study found larger right medial nuclei volumes in MDD compared to HC and relatively increased right compared to left whole and substructure volume ratios in MDD. The results suggest that amygdala substructure volumes may be involved in the pathophysiology of depression.',
#   'container-title': 'NeuroImage: Clinical',
#   'DOI': '10.1016/j.nicl.2021.102781',
#   'ISSN': '22131582',
#   'journalAbbreviation': 'NeuroImage: Clinical',
#   'language': 'en',
#   'note': 'PMID: 34384996',
#   'page': '102781',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Amygdala substructure volumes in Major Depressive Disorder',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S2213158221002254',
#   'volume': '31',
#   'author': [{'family': 'Roddy', 'given': 'Darren'},
#    {'family': 'Kelly', 'given': 'John R.'},
#    {'family': 'Farrell', 'given': 'Chloë'},
#    {'family': 'Doolin', 'given': 'Kelly'},
#    {'family': 'Roman', 'given': 'Elena'},
#    {'family': 'Nasa', 'given': 'Anurag'},
#    {'family': 'Frodl', 'given': 'Thomas'},
#    {'family': 'Harkin', 'given': 'Andrew'},
#    {'family': "O'Mara", 'given': 'Shane'},
#    {'family': "O'Hanlon", 'given': 'Erik'},
#    {'family': "O'Keane", 'given': 'Veronica'}],
#   'accessed': {'date-parts': [['2022', 1, 24]]},
#   'issued': {'date-parts': [['2021']]}},
#  {'id': 'eliotDumpDimorphismComprehensive2021',
#   'type': 'article-journal',
#   'container-title': 'Neuroscience & Biobehavioral Reviews',
#   'DOI': '10.1016/j.neubiorev.2021.02.026',
#   'ISSN': '01497634',
#   'journalAbbreviation': 'Neuroscience & Biobehavioral Reviews',
#   'language': 'en',
#   'note': 'PMID: 33621637',
#   'page': '667-697',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Dump the “dimorphism”: Comprehensive synthesis of human brain studies reveals few male-female differences beyond size',
#   'title-short': 'Dump the “dimorphism”',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763421000804',
#   'volume': '125',
#   'author': [{'family': 'Eliot', 'given': 'Lise'},
#    {'family': 'Ahmed', 'given': 'Adnan'},
#    {'family': 'Khan', 'given': 'Hiba'},
#    {'family': 'Patel', 'given': 'Julie'}],
#   'accessed': {'date-parts': [['2022', 1, 24]]},
#   'issued': {'date-parts': [['2021', 6]]}},
#  {'id': 'rakeshSocioeconomicStatusDeveloping2021',
#   'type': 'article-journal',
#   'abstract': 'A growing literature has shown associations between socioeconomic disadvantage and neural properties (such as brain structure and function). In this review, we aimed to synthesize findings on the neural correlates of so\xad cioeconomic status (SES) in youth samples across neuroimaging modalities. We also aimed to disentangle the effects of different SES measures (e.g., parent income and education) in our synthesis. We found relatively consistent patterns of positive associations between SES and both volume and cortical surface area of frontal regions, and amygdala, hippocampal, and striatal volume (with most consistent results for composite SES indices). Despite limited longitudinal work, results suggest that SES is associated with developmental trajectories of gray matter structure. Higher SES was also found to be associated with increased fractional anisotropy of some white matter tracts, although there were more null than positive findings. Finally, methodological heterogeneity in brain function and connectivity studies prevented us from making strong inferences. Based on our findings, we make recommendations for future research, discuss the role of mitigating factors, and implications for policy.',
#   'container-title': 'Neuroscience & Biobehavioral Reviews',
#   'DOI': '10.1016/j.neubiorev.2021.08.027',
#   'ISSN': '01497634',
#   'journalAbbreviation': 'Neuroscience & Biobehavioral Reviews',
#   'language': 'en',
#   'note': 'PMID: 34474050',
#   'page': '379-407',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Socioeconomic status and the developing brain – A systematic review of neuroimaging findings in youth',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763421003778',
#   'volume': '130',
#   'author': [{'family': 'Rakesh', 'given': 'Divyangana'},
#    {'family': 'Whittle', 'given': 'Sarah'}],
#   'accessed': {'date-parts': [['2022', 1, 24]]},
#   'issued': {'date-parts': [['2021', 11]]}},
#  {'id': 'deromeDevelopmentalTrajectoriesSubcortical2020',
#   'type': 'article-journal',
#   'abstract': 'Morphological abnormalities of subcortical structures have been consistently reported along the schizophrenia clinical spectrum, and they may play an important role in the pathophysiology of psychosis. However, the question arises whether these subcortical features are consequences of medication and illness chronicity, or if they contribute to the vulnerability to develop schizophrenia spectrum disorders. If some of the subcortical abnormalities could be evidenced in community adolescents expressing higher schizotypal traits (psychometric schizotypy), they could potentially shed light on vulnerability markers. To date, very few studies have examined the link between psychometric schizotypy and volumes of subcortical regions, and none of them have used a longitudinal design. This study sets out to investigate developmental trajectories of subcortical volumes in 110 community adolescents (12 to 20 years old), for whom MRI-scans were acquired over a period of 5 years, reaching a total of 297 scans. Analyses were conducted using Freesurfer, and schizotypal traits were measured with the Schizotypal Personality Questionnaire (SPQ). Using mixed model regression analyses following a region-ofinterest approach, we observed differential linear developmental trajectories in four subcortical structures when comparing higher versus lower scorers on the disorganized schizotypy dimension (bilateral hippocampus, left-lateral ventricle and left-pallidum) and the negative schizotypy dimension (bilateral pallidum, and rightthalamus). All results survived a threshold of p b .05 (FDR-corrected) while covarying for the effect of other psychological problems (externalized and internalized psychopathology). These results indicate that expression of higher levels of negative and disorganized schizotypy during adolescence was associated with neural markers linking schizotypy personality features to schizophrenia spectrum disorders.',
#   'container-title': 'Schizophrenia Research',
#   'DOI': '10.1016/j.schres.2020.02.005',
#   'ISSN': '09209964',
#   'journalAbbreviation': 'Schizophrenia Research',
#   'language': 'en',
#   'note': 'PMID: 32081537',
#   'page': '76-84',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Developmental trajectories of subcortical structures in relation to dimensional schizotypy expression along adolescence',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0920996420300815',
#   'volume': '218',
#   'author': [{'family': 'Derome', 'given': 'Mélodie'},
#    {'family': 'Zöller', 'given': 'Daniela'},
#    {'family': 'Modinos', 'given': 'Gemma'},
#    {'family': 'Schaer', 'given': 'Marie'},
#    {'family': 'Eliez', 'given': 'Stephan'},
#    {'family': 'Debbané', 'given': 'Martin'}],
#   'accessed': {'date-parts': [['2022', 1, 24]]},
#   'issued': {'date-parts': [['2020', 4]]}},
#  {'id': 'campbellAssociationsTestosteroneEstradiol2022',
#   'type': 'article-journal',
#   'abstract': 'Much is known about the development of the whole amygdala, but less is known about its structurally and functionally diverse subregions. One notable distinguishing feature is their wide range of androgen and estrogen receptor densities. Given the rise in pubertal hormones during adolescence, sex steroid levels as well as receptor sensitivity could influence age-related subregion volumes. Therefore, our goal was to evaluate the associations between the total amygdala and its subregion volumes in relation to sex hormones – estradiol and free testos\xad terone (FT) – as a function of age and genetic differences in androgen receptor (AR) sensitivity in a sample of 297 adolescents (46% female). In males, we found small effects of FT-by-age interactions in the total amygdala, portions of the basolateral complex, and the cortical and medial nuclei (CMN), with the CMN effects being moderated by AR sensitivity. For females, small effects were seen with increased genetic AR sensitivity relating to smaller basolateral complexes. However, none of these small effects passed multiple comparisons. Future larger studies are necessary to replicate these small, yet possibly meaningful effects of FT-by-age associations and modulation by AR sensitivity on amygdala development to ultimately determine if they contribute to known sex differences in emotional neurodevelopment.',
#   'container-title': 'Psychoneuroendocrinology',
#   'DOI': '10.1016/j.psyneuen.2021.105604',
#   'ISSN': '03064530',
#   'journalAbbreviation': 'Psychoneuroendocrinology',
#   'language': 'en',
#   'note': 'PMID: 34971856',
#   'page': '105604',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Associations between testosterone, estradiol, and androgen receptor genotype with amygdala subregions in adolescents',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0306453021004789',
#   'volume': '137',
#   'author': [{'family': 'Campbell', 'given': 'Claire E.'},
#    {'family': 'Mezher', 'given': 'Adam F.'},
#    {'family': 'Tyszka', 'given': 'J. Michael'},
#    {'family': 'Nagel', 'given': 'Bonnie J.'},
#    {'family': 'Eckel', 'given': 'Sandrah P.'},
#    {'family': 'Herting', 'given': 'Megan M.'}],
#   'accessed': {'date-parts': [['2022', 1, 24]]},
#   'issued': {'date-parts': [['2022', 3]]}},
#  {'id': 'caparelliGraphTheoryReveals2017',
#   'type': 'article-journal',
#   'container-title': 'Scientific Reports',
#   'DOI': '10.1038/s41598-017-14613-4',
#   'ISSN': '2045-2322',
#   'issue': '1',
#   'journalAbbreviation': 'Sci Rep',
#   'language': 'en',
#   'note': 'PMID: 29089582',
#   'page': '14392',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Graph theory reveals amygdala modules consistent with its anatomical subdivisions',
#   'URL': 'http://www.nature.com/articles/s41598-017-14613-4',
#   'volume': '7',
#   'author': [{'family': 'Caparelli', 'given': 'Elisabeth C.'},
#    {'family': 'Ross', 'given': 'Thomas J.'},
#    {'family': 'Gu', 'given': 'Hong'},
#    {'family': 'Liang', 'given': 'Xia'},
#    {'family': 'Stein', 'given': 'Elliot A.'},
#    {'family': 'Yang', 'given': 'Yihong'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2017', 12]]}},
#  {'id': 'gabard-durnamDevelopmentHumanAmygdala2014',
#   'type': 'article-journal',
#   'abstract': 'Functional connections (FC) between the amygdala and cortical and subcortical regions underlie a range of affective and cognitive processes. Despite the central role amygdala networks have in these functions, the normative developmental emergence of FC between the amygdala and the rest of the brain is still largely undeﬁned. This study employed amygdala subregion maps and resting-state functional magnetic resonance imaging to characterize the typical development of human amygdala FC from age 4 to 23 years old (n = 58). Amygdala FC with subcortical and limbic regions was largely stable across this developmental period. However, three cortical regions exhibited age-dependent changes in FC: amygdala FC with the medial prefrontal cortex (mPFC) increased with age, amygdala FC with a region including the insula and superior temporal sulcus decreased with age, and amygdala FC with a region encompassing the parahippocampal gyrus and posterior cingulate also decreased with age. The transition from childhood to adolescence (around age 10 years) marked an important change-point in the nature of amygdala–cortical FC. We distinguished unique developmental patterns of coupling for three amygdala subregions and found particularly robust convergence of FC for all subregions with the mPFC. These ﬁndings suggest that there are extensive changes in amygdala–cortical functional connectivity that emerge between childhood and adolescence.',
#   'container-title': 'NeuroImage',
#   'DOI': '10.1016/j.neuroimage.2014.03.038',
#   'ISSN': '10538119',
#   'journalAbbreviation': 'NeuroImage',
#   'language': 'en',
#   'note': 'PMID: 24662579',
#   'page': '193-207',
#   'source': 'DOI.org (Crossref)',
#   'title': 'The development of human amygdala functional connectivity at rest from 4 to 23years: A cross-sectional study',
#   'title-short': 'The development of human amygdala functional connectivity at rest from 4 to 23years',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811914001980',
#   'volume': '95',
#   'author': [{'family': 'Gabard-Durnam', 'given': 'Laurel J.'},
#    {'family': 'Flannery', 'given': 'Jessica'},
#    {'family': 'Goff', 'given': 'Bonnie'},
#    {'family': 'Gee', 'given': 'Dylan G.'},
#    {'family': 'Humphreys', 'given': 'Kathryn L.'},
#    {'family': 'Telzer', 'given': 'Eva'},
#    {'family': 'Hare', 'given': 'Todd'},
#    {'family': 'Tottenham', 'given': 'Nim'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2014', 7]]}},
#  {'id': 'fariaAmygdalaSubregionsTied2012',
#   'type': 'article-journal',
#   'container-title': 'Neuropsychopharmacology',
#   'DOI': '10.1038/npp.2012.72',
#   'ISSN': '0893-133X, 1740-634X',
#   'issue': '10',
#   'journalAbbreviation': 'Neuropsychopharmacol',
#   'language': 'en',
#   'note': 'PMID: 22617357',
#   'page': '2222-2232',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Amygdala Subregions Tied to SSRI and Placebo Response in Patients with Social Anxiety Disorder',
#   'URL': 'http://www.nature.com/articles/npp201272',
#   'volume': '37',
#   'author': [{'family': 'Faria', 'given': 'Vanda'},
#    {'family': 'Appel', 'given': 'Lieuwe'},
#    {'family': 'Åhs', 'given': 'Fredrik'},
#    {'family': 'Linnman', 'given': 'Clas'},
#    {'family': 'Pissiota', 'given': 'Anna'},
#    {'family': 'Frans', 'given': 'Örjan'},
#    {'family': 'Bani', 'given': 'Massimo'},
#    {'family': 'Bettica', 'given': 'Paolo'},
#    {'family': 'Pich', 'given': 'Emilio M'},
#    {'family': 'Jacobsson', 'given': 'Eva'},
#    {'family': 'Wahlstedt', 'given': 'Kurt'},
#    {'family': 'Fredrikson', 'given': 'Mats'},
#    {'family': 'Furmark', 'given': 'Tomas'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2012', 9]]}},
#  {'id': 'alarconDevelopmentalSexDifferences2015',
#   'type': 'article-journal',
#   'abstract': "During adolescence, considerable social and biological changes occur that interact with functional brain maturation, some of which are sex-speciﬁc. The amygdala is one brain area that has displayed sexual dimorphism, speciﬁcally in socio-affective (superﬁcial amygdala [SFA]), stress (centromedial amygdala [CMA]), and learning and memory (basolateral amygdala [BLA]) processing. The amygdala has also been implicated in mood and anxiety disorders which display sex-speciﬁc features, most prominently observed during adolescence. Using functional magnetic resonance imaging (fMRI), the present study examined the interaction of age and sex on resting state functional connectivity (RSFC) of amygdala sub-regions, BLA and SFA, in a sample of healthy adolescents between the ages 10 and 16 years (n = 122, 71 boys). Whole-brain, voxel-wise partial correlation analyses were conducted to determine RSFC of bilateral BLA and SFA seed regions, created using the Eickhoff–Zilles maximum probability maps based on cytoarchitectonic mapping and FMRIB's Integrated Registration and Segmentation Tool (FIRST). Monte Carlo simulation was implemented to correct for multiple comparisons (threshold of 53 contiguous voxels with a z-value ≥ 2.25). Results indicated that with increasing age, there was a corresponding decrease in RSFC between both amygdala sub-regions and parieto-occipital cortices, with a concurrent increase in RSFC with medial prefrontal cortex (mPFC). Speciﬁcally, boys and girls demonstrated increased coupling of mPFC and left and right SFA with age, respectively; however, neither sex showed increased connectivity between mPFC and BLA, which could indicate relative immaturity of fronto-limbic networks that is similar across sex. A dissociation in connectivity between BLA- and SFA-parieto-occipital RSFC emerged, in which girls had weaker negative RSFC between SFA and parieto-occipital regions and boys had weaker negative RSFC of BLA and parietooccipital regions with increased age, both standing in contrast to adult patterns of amygdala sub-regional RSFC. The present ﬁndings suggest relative immaturity of amygdala sub-regional RSFC with parieto-occipital cortices during adolescence, with unique patterns in both sexes that may support memory and socio-affective processing in boys and girls, respectively. Understanding the underlying normative functional architecture of brain networks associated with the amygdala during adolescence may better inform future research of the neural features associated with increased risk for internalizing psychopathology.",
#   'container-title': 'NeuroImage',
#   'DOI': '10.1016/j.neuroimage.2015.04.013',
#   'ISSN': '10538119',
#   'journalAbbreviation': 'NeuroImage',
#   'language': 'en',
#   'note': 'PMID: 25887261',
#   'page': '235-244',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Developmental sex differences in resting state functional connectivity of amygdala sub-regions',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811915003031',
#   'volume': '115',
#   'author': [{'family': 'Alarcón', 'given': 'Gabriela'},
#    {'family': 'Cservenka', 'given': 'Anita'},
#    {'family': 'Rudolph', 'given': 'Marc D.'},
#    {'family': 'Fair', 'given': 'Damien A.'},
#    {'family': 'Nagel', 'given': 'Bonnie J.'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2015', 7]]}},
#  {'id': 'kimSexDifferencesAmygdala2012',
#   'type': 'article-journal',
#   'abstract': 'Each subregion of the amygdala is characterized by a distinct cytoarchitecture and function. However, most previous studies on sexual dimorphism and aging have assessed differences in the structure of the amygdala at the level of the amygdala in its entirety rather than at the subregional level. Using an amygdala subregional shape analysis, we investigated the effects of sex, age, and the sex × age interaction on the subregion after controlling for intracranial volume. We found the main effect of age in the subregions and the effect of sex in the superﬁcial nucleus, which showed that men had a larger mean radius than women. We also found a sex × age interaction in the centromedial nucleus, in that the radius of the centromedial nucleus showed a steeper decline with age in women compared with men. Regarding the amygdala volume as a whole, we found only an age effect and did not ﬁnd any other signiﬁcant difference between genders. The sex difference in the amygdala subregion and its relevance to the circulating gonadal hormone were discussed.',
#   'container-title': 'NeuroImage',
#   'DOI': '10.1016/j.neuroimage.2012.02.025',
#   'ISSN': '10538119',
#   'issue': '4',
#   'journalAbbreviation': 'NeuroImage',
#   'language': 'en',
#   'note': 'PMID: 22374477',
#   'page': '2054-2061',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Sex differences in amygdala subregions: Evidence from subregional shape analysis',
#   'title-short': 'Sex differences in amygdala subregions',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811912002029',
#   'volume': '60',
#   'author': [{'family': 'Kim', 'given': 'Hengjun J.'},
#    {'family': 'Kim', 'given': 'Namkug'},
#    {'family': 'Kim', 'given': 'Sehyun'},
#    {'family': 'Hong', 'given': 'Seokjun'},
#    {'family': 'Park', 'given': 'Kyungmo'},
#    {'family': 'Lim', 'given': 'Sabina'},
#    {'family': 'Park', 'given': 'Jung-Mi'},
#    {'family': 'Na', 'given': 'Byungjo'},
#    {'family': 'Chae', 'given': 'Younbyoung'},
#    {'family': 'Lee', 'given': 'Jeongchan'},
#    {'family': 'Yeo', 'given': 'Sujung'},
#    {'family': 'Choe', 'given': 'Il-Hwan'},
#    {'family': 'Cho', 'given': 'Seung-Yeon'},
#    {'family': 'Cho', 'given': 'Gyunggoo'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2012', 5]]}},
#  {'id': 'michelyDistinctProcessingAversive2020',
#   'type': 'article-journal',
#   'abstract': 'BACKGROUND: The amygdala is an anatomically complex medial temporal brain structure whose subregions are considered to serve distinct functions. However, their precise role in mediating human aversive experience remains ill understood.\nMETHODS: We used functional magnetic resonance imaging in 39 healthy volunteers with varying levels of trait anxiety to assess distinct contributions of the basolateral amygdala (BLA) and centromedial amygdala to anticipation and experience of aversive events. Additionally, we examined the relationship between any identiﬁed functional subspecialization and measures of subjective reported aversion and trait anxiety.\nRESULTS: Our results show that the centromedial amygdala is responsive to aversive outcomes but insensitive to predictive aversive cues. In contrast, the BLA encodes an aversive prediction error that quantiﬁes whether cues and outcomes are worse than expected. A neural representation within the BLA for distinct threat levels was mirrored in self-reported subjective anxiety across individuals. Furthermore, high trait-anxious individuals were characterized by indiscriminately heightened BLA activity in response to aversive cues, regardless of actual threat level.\nCONCLUSIONS: Our results demonstrate that amygdala subregions are distinctly engaged in processing of aversive experience, with elevated and undifferentiated BLA responses to threat emerging as a potential neurobiological mediator of vulnerability to anxiety disorders.',
#   'container-title': 'Biological Psychiatry: Cognitive Neuroscience and Neuroimaging',
#   'DOI': '10.1016/j.bpsc.2019.07.008',
#   'ISSN': '24519022',
#   'issue': '3',
#   'journalAbbreviation': 'Biological Psychiatry: Cognitive Neuroscience and Neuroimaging',
#   'language': 'en',
#   'note': 'PMID: 31542358',
#   'page': '291-300',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Distinct Processing of Aversive Experience in Amygdala Subregions',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S2451902219302010',
#   'volume': '5',
#   'author': [{'family': 'Michely', 'given': 'Jochen'},
#    {'family': 'Rigoli', 'given': 'Francesco'},
#    {'family': 'Rutledge', 'given': 'Robb B.'},
#    {'family': 'Hauser', 'given': 'Tobias U.'},
#    {'family': 'Dolan', 'given': 'Raymond J.'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2020', 3]]}},
#  {'id': 'ballResponsePropertiesHuman2007',
#   'type': 'article-journal',
#   'container-title': 'PLoS ONE',
#   'DOI': '10.1371/journal.pone.0000307',
#   'ISSN': '1932-6203',
#   'issue': '3',
#   'journalAbbreviation': 'PLoS ONE',
#   'language': 'en',
#   'note': 'PMID: 17375193',
#   'page': 'e307',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Response Properties of Human Amygdala Subregions: Evidence Based on Functional MRI Combined with Probabilistic Anatomical Maps',
#   'title-short': 'Response Properties of Human Amygdala Subregions',
#   'URL': 'https://dx.plos.org/10.1371/journal.pone.0000307',
#   'volume': '2',
#   'author': [{'family': 'Ball', 'given': 'Tonio'},
#    {'family': 'Rahm', 'given': 'Benjamin'},
#    {'family': 'Eickhoff', 'given': 'Simon B.'},
#    {'family': 'Schulze-Bonhage', 'given': 'Andreas'},
#    {'family': 'Speck', 'given': 'Oliver'},
#    {'family': 'Mutschler', 'given': 'Isabella'}],
#   'editor': [{'family': 'He', 'given': 'Sheng'}],
#   'accessed': {'date-parts': [['2021', 12, 9]]},
#   'issued': {'date-parts': [['2007', 3, 21]]}},
#  {'id': 'fruhholzAmygdalaSubregionsDifferentially2013',
#   'type': 'article-journal',
# ...
#   'title-short': 'Testosterone and Its Effects on Human Male Adolescent Mood and Behavior',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S1054139X14002250',
#   'volume': '55',
#   'author': [{'family': 'Duke', 'given': 'Sally Anne'},
#    {'family': 'Balzer', 'given': 'Ben W.R.'},
#    {'family': 'Steinbeck', 'given': 'Katharine S.'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2014', 9]]}},
#  {'id': 'holderPubertyAdolescenceTime2014',
#   'type': 'article-journal',
#   'abstract': 'Puberty and adolescence are major life transitions during which an individual’s physiology and behavior changes from that of a juvenile to that of an adult. Here we review studies documenting the effects of stressors during pubertal and adolescent development on the adult brain and behavior. The experience of complex or compound stressors during puberty/adolescence generally increases stress reactivity, increases anxiety and depression, and decreases cognitive performance in adulthood. These behavioral changes correlate with decreased hippocampal volumes and alterations in neural plasticity. Moreover, stressful experiences during puberty disrupt behavioral responses to gonadal hormones both in sexual performance and on cognition and emotionality. These behavioral changes correlate with altered estrogen receptor densities in some estrogen-concentrating brain areas, suggesting a remodeling of the brain’s response to hormones. A hypothesis is presented that activation of the immune system results in chronic neuroinﬂammation that may mediate the alterations of hormone-modulated behaviors in adulthood.',
#   'container-title': 'Frontiers in Neuroendocrinology',
#   'DOI': '10.1016/j.yfrne.2013.10.004',
#   'ISSN': '00913022',
#   'issue': '1',
#   'journalAbbreviation': 'Frontiers in Neuroendocrinology',
#   'language': 'en',
#   'note': 'PMID: 24184692',
#   'page': '89-110',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Puberty and adolescence as a time of vulnerability to stressors that alter neurobehavioral processes',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0091302213000654',
#   'volume': '35',
#   'author': [{'family': 'Holder', 'given': 'Mary K.'},
#    {'family': 'Blaustein', 'given': 'Jeffrey D.'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2014', 1]]}},
#  {'id': 'swartzAgerelatedChangesStructure2014',
#   'type': 'article-journal',
#   'abstract': 'The uncinate fasciculus is a major white matter tract that provides a crucial link between areas of the human brain that underlie emotion processing and regulation. Speciﬁcally, the uncinate fasciculus is the major direct ﬁber tract that connects the prefrontal cortex and the amygdala. The aim of the present study was to use a multi-modal imaging approach in order to simultaneously examine the relation between structural connectivity of the uncinate fasciculus and functional activation of the amygdala in a youth sample (children and adolescents). Participants were 9 to 19 years old and underwent diffusion tensor imaging (DTI) and functional magnetic resonance imaging (fMRI). Results indicate that greater structural connectivity of the uncinate fasciculus predicts reduced amygdala activation to sad and happy faces. This effect is moderated by age, with younger participants exhibiting a stronger relation. Further, decreased amygdala activation to sad faces predicts lower internalizing symptoms. These results provide important insights into brain structure–function relationships during adolescence, and suggest that greater structural connectivity of the uncinate fasciculus may facilitate regulation of the amygdala, particularly during early adolescence. These ﬁndings also have implications for understanding the relation between brain structure, function, and the development of emotion regulation difﬁculties, such as internalizing symptoms.',
#   'container-title': 'NeuroImage',
#   'DOI': '10.1016/j.neuroimage.2013.08.018',
#   'ISSN': '10538119',
#   'journalAbbreviation': 'NeuroImage',
#   'language': 'en',
#   'note': 'PMID: 23959199',
#   'page': '212-220',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Age-related changes in the structure and function of prefrontal cortex–amygdala circuitry in children and adolescents: A multi-modal imaging approach',
#   'title-short': 'Age-related changes in the structure and function of prefrontal cortex–amygdala circuitry in children and adolescents',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S1053811913008720',
#   'volume': '86',
#   'author': [{'family': 'Swartz', 'given': 'Johnna R.'},
#    {'family': 'Carrasco', 'given': 'Melisa'},
#    {'family': 'Wiggins', 'given': 'Jillian Lee'},
#    {'family': 'Thomason', 'given': 'Moriah E.'},
#    {'family': 'Monk', 'given': 'Christopher S.'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2014', 2]]}},
#  {'id': 'scherfAmygdalaAgentChange2013',
#   'type': 'article-journal',
#   'abstract': 'This article is part of a Special Issue “Puberty and Adolescence”. A unique component of adolescent development is the need to master new developmental tasks in which peer interactions become primary (for the purposes of becoming autonomous from parents, forming intimate friendships, and romantic/sexual partnerships). Previously, it has been suggested that the ability to master these tasks requires an important re-organization in the relation between perceptual, motivational, affective, and cognitive systems in a very general and broad way that is fundamentally inﬂuenced by the infusion of sex hormones during pubertal development (Scherf et al., 2012). Herein, we extend this argument to suggest that the amygdala, which is vastly connected with cortical and subcortical regions and contains sex hormone receptors, may lie at the heart of this re-organization. We propose that during adolescent development there is a shift in the attribution of relevance to existing stimuli and contexts that is mediated by the amygdala (e.g., heightened relevance of peer faces, reduced relevance of physical distance from parents). As a result, amygdala inputs to existing stable neural networks are re-weighted (increased or decreased), which destabilizes the functional interactions among regions within these networks and allows for a critical restructuring of the network functional organization. This process of network re-organization enables processing of qualitatively new kinds of social information and the emergence of novel behaviors that support mastery of adolescent-speciﬁc developmental tasks.',
#   'container-title': 'Hormones and Behavior',
#   'DOI': '10.1016/j.yhbeh.2013.05.011',
#   'ISSN': '0018506X',
#   'issue': '2',
#   'journalAbbreviation': 'Hormones and Behavior',
#   'language': 'en',
#   'note': 'PMID: 23756154',
#   'page': '298-313',
#   'source': 'DOI.org (Crossref)',
#   'title': 'The amygdala: An agent of change in adolescent neural networks',
#   'title-short': 'The amygdala',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0018506X13001219',
#   'volume': '64',
#   'author': [{'family': 'Scherf', 'given': 'K. Suzanne'},
#    {'family': 'Smyth', 'given': 'Joshua M.'},
#    {'family': 'Delgado', 'given': 'Mauricio R.'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2013', 7]]}},
#  {'id': 'burghyDevelopmentalPathwaysAmygdalaprefrontal2012',
#   'type': 'article-journal',
#   'container-title': 'Nature Neuroscience',
#   'DOI': '10.1038/nn.3257',
#   'ISSN': '1097-6256, 1546-1726',
#   'issue': '12',
#   'journalAbbreviation': 'Nat Neurosci',
#   'language': 'en',
#   'note': 'PMID: 23143517',
#   'page': '1736-1741',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Developmental pathways to amygdala-prefrontal function and internalizing symptoms in adolescence',
#   'URL': 'http://www.nature.com/articles/nn.3257',
#   'volume': '15',
#   'author': [{'family': 'Burghy', 'given': 'Cory A'},
#    {'family': 'Stodola', 'given': 'Diane E'},
#    {'family': 'Ruttle', 'given': 'Paula L'},
#    {'family': 'Molloy', 'given': 'Erin K'},
#    {'family': 'Armstrong', 'given': 'Jeffrey M'},
#    {'family': 'Oler', 'given': 'Jonathan A'},
#    {'family': 'Fox', 'given': 'Michelle E'},
#    {'family': 'Hayes', 'given': 'Andrea S'},
#    {'family': 'Kalin', 'given': 'Ned H'},
#    {'family': 'Essex', 'given': 'Marilyn J'},
#    {'family': 'Davidson', 'given': 'Richard J'},
#    {'family': 'Birn', 'given': 'Rasmus M'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2012', 12]]}},
#  {'id': 'yurgelun-toddEmotionalCognitiveChanges2007',
#   'type': 'article-journal',
#   'container-title': 'Current Opinion in Neurobiology',
#   'DOI': '10.1016/j.conb.2007.03.009',
#   'ISSN': '09594388',
#   'issue': '2',
#   'journalAbbreviation': 'Current Opinion in Neurobiology',
#   'language': 'en',
#   'note': 'PMID: 17383865',
#   'page': '251-257',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Emotional and cognitive changes during adolescence',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0959438807000414',
#   'volume': '17',
#   'author': [{'family': 'Yurgelun-Todd', 'given': 'Deborah'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2007', 4]]}},
#  {'id': 'zahn-waxlerInternalizingProblemsChildhood2000',
#   'type': 'article-journal',
#   'abstract': 'The focus of this article is on internalizing problems that are experienced by children and adolescents. We provide an historical perspective, selectively examine the current state of knowledge, consider advances and gaps in what is known, and identify new research directions. Diagnosis, epidemiology, theory, and research first are considered separately for anxiety and depressive disorders. These internalizing problems, however, whether clinical or subclinical, share many common features and show high comorbidity rates. We emphasize the importance of systematic analysis of comorbid anxiety and depression, including their comorbidity with externalizing problems. This could lead to more valid classification of subtypes of internalizing problems and further an understanding of the diverse conditions that constitute internalized distress. We highlight the need to study anxiety and depression within a developmental psychopathology framework, as well as to include both categorical and dimensional assessments of these problems in the same research designs. This will be essential for understanding the complex interplay of biological and environmental processes that contribute to the emergence, progression, and amelioration of internalizing problems over time.',
#   'container-title': 'Development and Psychopathology',
#   'DOI': '10.1017/S0954579400003102',
#   'ISSN': '0954-5794, 1469-2198',
#   'issue': '3',
#   'journalAbbreviation': 'Dev Psychopathol',
#   'language': 'en',
#   'page': '443-466',
#   'source': 'DOI.org (Crossref)',
#   'title': 'Internalizing problems of childhood and adolescence: Prospects, pitfalls, and progress inunderstanding the development of anxiety and depression',
#   'title-short': 'Internalizing problems of childhood and adolescence',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0954579400003102/type/journal_article',
#   'volume': '12',
#   'author': [{'family': 'Zahn–Waxler', 'given': 'Carolyn'},
#    {'family': 'Klimes–Dougan', 'given': 'Bonnie'},
#    {'family': 'Slattery', 'given': 'Marcia J.'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2000', 9]]}},
#  {'id': 'spearAdolescentBrainAgerelated2000',
#   'type': 'article-journal',
#   'abstract': 'To successfully negotiate the developmental transition between youth and adulthood, adolescents must maneuver this often stressful period while acquiring skills necessary for independence. Certain behavioral features, including age-related increases in social behavior and risk-taking/novelty-seeking, are common among adolescents of diverse mammalian species and may aid in this process. Reduced positive incentive values from stimuli may lead adolescents to pursue new appetitive reinforcers through drug use and other risk-taking behaviors, with their relative insensitivity to drugs supporting comparatively greater per occasion use. Pubertal increases in gonadal hormones are a hallmark of adolescence, although there is little evidence for a simple association of these hormones with behavioral change during adolescence. Prominent developmental transformations are seen in prefrontal cortex and limbic brain regions of adolescents across a variety of species, alterations that include an apparent shift in the balance between mesocortical and mesolimbic dopamine systems. Developmental changes in these stressor-sensitive regions, which are critical for attributing incentive salience to drugs and other stimuli, likely contribute to the unique characteristics of adolescence. ᭧ 2000 Elsevier Science Ltd. All rights reserved.',
#   'container-title': 'Neuroscience & Biobehavioral Reviews',
#   'DOI': '10.1016/S0149-7634(00)00014-2',
#   'ISSN': '01497634',
#   'issue': '4',
#   'journalAbbreviation': 'Neuroscience & Biobehavioral Reviews',
#   'language': 'en',
#   'note': 'PMID: 10817843',
#   'page': '417-463',
#   'source': 'DOI.org (Crossref)',
#   'title': 'The adolescent brain and age-related behavioral manifestations',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0149763400000142',
#   'volume': '24',
#   'author': [{'family': 'Spear', 'given': 'L.P.'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2000', 6]]}},
#  {'id': 'phuongFormalAlgorithmsTransformers2022',
#   'type': 'article',
#   'abstract': 'This document aims to be a self-contained, mathematically precise overview of transformer architectures and algorithms (not results). It covers what transformers are, how they are trained, what they are used for, their key architectural components, and a preview of the most prominent models. The reader is assumed to be familiar with basic ML terminology and simpler neural network architectures such as MLPs.',
#   'language': 'en',
#   'note': 'arXiv:2207.09238 [cs]',
#   'number': 'arXiv:2207.09238',
#   'publisher': 'arXiv',
#   'source': 'arXiv.org',
#   'title': 'Formal Algorithms for Transformers',
#   'URL': 'http://arxiv.org/abs/2207.09238',
#   'author': [{'family': 'Phuong', 'given': 'Mary'},
#    {'family': 'Hutter', 'given': 'Marcus'}],
#   'accessed': {'date-parts': [['2023', 5, 15]]},
#   'issued': {'date-parts': [['2022', 7, 19]]}},
#  {'id': 'vaswaniAttentionAllYou',
#   'type': 'article-journal',
#   'abstract': 'The dominant sequence transduction models are based on complex recurrent or convolutional neural networks that include an encoder and a decoder. The best performing models also connect the encoder and decoder through an attention mechanism. We propose a new simple network architecture, the Transformer, based solely on attention mechanisms, dispensing with recurrence and convolutions entirely. Experiments on two machine translation tasks show these models to be superior in quality while being more parallelizable and requiring signiﬁcantly less time to train. Our model achieves 28.4 BLEU on the WMT 2014 Englishto-German translation task, improving over the existing best results, including ensembles, by over 2 BLEU. On the WMT 2014 English-to-French translation task, our model establishes a new single-model state-of-the-art BLEU score of 41.0 after training for 3.5 days on eight GPUs, a small fraction of the training costs of the best models from the literature.',
#   'language': 'en',
#   'source': 'Zotero',
#   'title': 'Attention is All you Need',
#   'author': [{'family': 'Vaswani', 'given': 'Ashish'},
#    {'family': 'Shazeer', 'given': 'Noam'},
#    {'family': 'Parmar', 'given': 'Niki'},
#    {'family': 'Uszkoreit', 'given': 'Jakob'},
#    {'family': 'Jones', 'given': 'Llion'},
#    {'family': 'Gomez', 'given': 'Aidan N'},
#    {'family': 'Kaiser', 'given': 'Łukasz'},
#    {'family': 'Polosukhin', 'given': 'Illia'}]}]

# %%
docs = json.load(open('docs.json', 'r'))

# %%
p = docs[0]['attachments'][0]['path']
p
# Out:
# 'Journal Article/新井 et al_2015_カルボニルストレス代謝障害と統合失調症.pdf'

# %%
import fitz
import unicodedata
from dehyphen import FlairScorer, text_to_format
import langdetect

scorer = FlairScorer(lang="en")

# %%
base = Path('/Users/hiro/Library/CloudStorage/OneDrive-Personal/ZotAttachments')

# %%
doc = fitz.open(base / p)

# %%
def to_plain(lst):
    res = []
    for l1 in lst:
        for l2 in l1:
            for word in l2:
                res.append(word)
    return ' '.join(res).replace('  ', ' ')

def dehyphen(t):
    fmt = text_to_format(t)
    fixed_hyphens = scorer.dehyphen(fmt)
    return to_plain(fixed_hyphens)

def remove_newline(t):
    lines = t.split('\n')
    for i in range(len(lines) - 1):
        if len(lines[i]) > 0 and lines[i][-1].isascii() and len(lines[i+1]) > 0 and lines[i+1][0].isascii():
            lines[i] += ' '
    return ''.join(lines).replace('  ', ' ')

lang = None
for i, page in enumerate(doc):
    t = page.get_text()
    if lang is None:
        lang = langdetect.detect(t)
    t = unicodedata.normalize("NFKC", t)
    if lang == 'en':
        t = dehyphen(t)
    elif lang == 'ja':
        t = remove_newline(t)
    print(i, t)
# Out:
# 0 27日本生物学的精神医学会誌 26 巻 1 号はじめに 統合失調症研究における克服すべき点として異種性の回避が挙げられる。統合失調症の診断は臨床所見や経過観察に基づいており,発症の病因と病態を示すバイオマーカーに基づいた診断基準は未だ存在しない。したがって,統合失調症の早期診断,治療,予防法の創出のためには,異種性回避を念頭にしたバイオマーカーの同定とその分子基盤に基づいた病因,病態の理解が重要である。筆者らは,一部の統合失調症患者に見られるカルボニルストレス代謝障害の同定1,3)とカルボニルストレスを呈する症例の臨床経過と特徴2,16)を明らかにしてきた。さらに,治療法の開発に向けて,カルボニルストレス解毒作用をもつピリドキサミン(ビタミン B6 成分の一つ)を用いた医師主導治験を実施した。 勝田らの研究グループは,急性期症例でのカルボニルストレスマーカーの変動を確認し,筆者らと同様にビタミン B6 補充療法の有用性と臨床特徴,経過との関連を報告している12)。国外では,フランスのグループが,蛍光性を有する終末糖化産物(Advanced glycation end products,AGEs)を AGE Reader(Diagnoptics Technologies B.V.)を利用して測定を行い,AGEs 蓄積を統合失調症で報告している13)。統合失調症に特異的なカルボニルストレスマーカー(ペントシジン,ビタミン B6)は,症例の階層化と病因,病態研究のツールとなることが期待される。これまでの研究から,ペントシジン値は入院患者に比べて外来患者で有意に低下し,また,数年間の追跡研究においても,ペントシジン低下と臨床症状の改善に相関が認められている。 一般的なマーカーの定義は,通常の生物学的過程,病理学的過程,もしくは治療的介入に対する薬理学的応答の指標として,客観的に測定され評価される特性とされ(表 1),基礎研究の成果を臨床応用していくためにも統合失調症の真のバイオマーカー同定へ期待が寄せられている。本稿で紹介するカルボニルストレスマーカーは,ある特定の比較的均一な  Carbonyl stress dysfunction in a subpopulation of schizophrenia *公益財団法人東京都医学総合研究所 精神行動医学研究分野 統合失調症・うつ病プロジェクト(〒 156 ─8506 東京都世田谷区 上 北 沢 2 ─1 ─6)Makoto Arai, Akiko Kobori, Mitsuhiro Miyashita, Kazuya Toriumi, Yasue Horiuchi, Sachiko Hatakeyama, Miki Uchida, Tomoko Inoue, Masanari Itokawa:Department of Psychiatry and Behavioral Sciences, Tokyo Metropolitan Institute of Medical Science. 2 ─1 ─6, Kamikitazawa, Setagaya ─ku, Tokyo 156 ─8506, Japan【新井 誠 E ─mail:arai ─mk@igakuken.or.jp】1.カルボニルストレス代謝障害と統合失調症新井 誠* 小堀 晶子* 宮下 光弘* 鳥海 和也* 堀内 泰江* 畠山 幸子* 内田 美樹* 井上 智子* 糸川 昌成*抄録:統合失調症の精力的なゲノム研究が世界的に取り組まれているものの,統合失調症の病態生理が不均一であるが故に(異種性),その分子基盤を理解する際の大きな障壁となっている。筆者らは,これまでも臨床的な側面から特徴的な病像を呈する症例を集積し,かつ家系症例や希少症例を軸にして,個々の症例が有する分子基盤の一端を一般症例へ敷衍するというストラテジーを実践してきた。この研究手法により,まれな遺伝子変異を持つ家系症例から「カルボニルストレス」という代謝経路の障害を見出し,一般症例のおよそ 2 割に同じカルボニルストレス代謝の障害をもつ比較的均一な亜群を同定した。また,カルボニルストレスを呈する症例群の臨床的特徴を明らかにするとともに,カルボニルストレスの解毒作用をもつピリドキサミンを用いた医師主導治験を実施した。本稿では,これまでのカルボニルストレス性統合失調症について概説し,統合失調症研究における我々の将来展望�について述べた。日本生物学的精神医学会誌 26(1):27 ─33,�2015 Key words:advanced glycation end products,oxidative stress,glyoxalase,vitamin B6,pentosidine,  personalized medicine特集 2酸化ストレス・炎症と精神疾患
# 1 28 Japanese Journal of Biological Psychiatry Vol.26, No.1, 2015統合失調症の亜群における代謝制御機構の解明,発症機序の解明,病態の改善に向けた分子基盤を探る一助となる可能性が高い。1.統合失調症と AGEs,グリオキサラーゼ 統合失調症は,幻覚や妄想が特徴的な精神疾患であり,それに伴って,人との交流や社会生活を営む機能が障害され,病識の障害といった特徴を併せもつ。疾患の異種性から病因,病態の理解が難航しているものの,発症早期からの介入によって予後が軽減され,回復可能な疾患であることも明らかになりつつある。また,陽性症状だけでなく陰性症状や認知機能障害の改善や薬物による副作用軽減を発揮する新薬の開発が希求されている。 近年,統合失調症をはじめ精神疾患研究では,酸化ストレスやレドックス代謝の障害を病態仮説とした研究が精力的になされている23,26)。筆者らもまた,酸化ストレスが関与する糖化を軸にした解析を継続している。メイラード反応は,蛋白質のアミノ基と糖のカルボニル基が非酵素的に反応することによって開始され,その結果,可逆的なシッフ塩基の形成に引き続きシッフ塩基がアマドリ転位によって安定なアマドリ化合物を形成する。アマドリ化合物は,脱水,酸化,転位などの複数の反応過程を経て,不可逆的な終末糖化産物である AGEs を形成する(図 1)。また,糖や脂質,アミノ酸などは酸化,脂質過酸化反応の結果,種々の反応性カルボニル化合物であるメチルグリオキサール,グリオキサール,3 ─デオキシグルコソンを生成し,AGEs形成を亢進する。血液,尿,組織にみられる代表的な AGEs の構造体としては,CML,CEL,MOLD,GOLD,MG ─H1 などが知られ,これらの構造体は HPLC や質量分析法を組み合わせた LC ─MS/MS の手法により測定をすることが可能である。 AGEs 修飾はさまざまな疾患に関与していることがこれまでの先行研究から明らかにされている10,19,22) (図 2)。特に,糖尿病7),血液透析患者18),慢性腎疾患21)といった内科系疾患を中心とした研究が主であったが,近年は精神疾患25)とのかかわりも注目されるようになってきている。生体内において,反応性に富むメチルグリオキサールはグルタチオン依存的律速酵素であるグリオキサラーゼ 1(glyoxalase I:GLO1)によって解毒される。この GLO1 蛋白質, mRNA あるいは酵素活性との関連については,気分障害6),自閉症11),不安障害20),アルコール依存15),認知症14)での関連が報告されている。 筆者らは,GLO1 のゲノム解析において,フレームシフト変異(p.T27NfsX15,p.P122LfsX27),ミスセンス変異(p.Glu111Ala)を同定した。これらの変異では,GLO1 蛋白質の酵素活性が野生型の約40 ~ 50%低下(フレームシフト変異),約 15 ~ 20%低下(ミスセンス変異)していた。最近,さらに新たなフレームシフト変異(p.Lys157IlefsX11)をペントシジン高値(> 400ng/mL)の症例から同定した。これらの結果は,遺伝子変異によるグリオキサラーゼ代謝の破綻に起因するカルボニルストレスが統合失調症と関連することを示唆し,GLO1 変異をもつ症例では,発症以前からカルボニルスストレス状態に曝露され,AGEs の一つであるペントシジンによるタンパク質修飾,ビタミン B6 欠乏が生じ,統合失調症の発症の要因となっていた可能性も 種類 マーカー  用途 診断 diagnostic marker 疾患を早期に診断する 予後 prognostic marker 疾患の経過を予測する 薬力学 pharmacodynamic marker 薬剤の作用機序を理解する 予測 predictive marker 治療による効果を予測する 代替 surrogate marker 臨床試験のエンドポイントを代替する モニタリング monitoring marker 疾患の判断や治療への反応性を判断する 患者層別 stratification marker 特定の患者群の選別する 安全性・毒性 safety/toxicity marker 薬物の安全性や毒性を評価するマーカーとは,「通常の生物学的過程,病理学的過程,もしくは治療的介入に対する薬理学的応答の指標として,客観的に測定され評価される特性」と定義され,広義には,日常診療で用いられるバイタルサインや,生化学検査,血液検査,腫瘍マーカーなどの各種臨床検査値や画像診断データなどが含まれる(Biomarkers Definitions Working Group(2001)Clin Pharmacol Ther, 69:89─95)表 1 マーカーの種類と定義林邦彦(2013)医薬品開発におけるバイオマーカーの役割.医薬産業政策研究所リサーチペーパー・シリーズ,57:5より改変引用)
# 2 29日本生物学的精神医学会誌 26 巻 1 号推測される。2.統合失調症とカルボニルストレス カルボニルストレスの消去系にはグリオキサラーゼ代謝が全身性に機能している。また,ピリドキサミンはカルボニル化合物を捕捉する能力をもつカルボニルスカベンジャーとして作用している。筆者らは,糖尿病がなく腎機能が正常で統合失調症の診断基準を満たす 45 名と健常者 61 名を対象にして分析を実施した結果,統合失調症患者のペントシジン値は,健常者のおよそ 1.7 倍にまで達していることを報告した3)。また,ペントシジンレベルが顕著な上昇を示した統合失調症の症例は,重篤な精神症状を呈して長期入院している治療抵抗性の症例であった。さらに,統合失調症患者 156 例および健常者221 例の末梢血を利用した再検討では,統合失調症の 11.8%でカルボニルストレスの亢進を認めた17)。一方,健常者群ではわずか 0.01%であった。カルボニルストレスを呈する患者群では,カルボニルストレスのない患者群と比較して,入院患者の割合が高く,入院期間が 4.2 倍と長期に及び,投与されている抗精神病薬の総投与量が多いという特徴も同定し図1 代表的なAGEsの生成過程 AGEs として知られる MOLD(methyl─glyoxal─lysine dimer),CEL[Nε─(carboxyethyl)lysine], CML[Nε─(carboxymethyl)lysine],GOLD(glyoxal─lysine dimer)などはメイラード反応,ポリオール経路,脂質過酸化などによって産生される。(Ott C, et al(2014)Redox Biol, 2:411─429.19)より引用) Condensation pH  7 reversible pH  7 Maillard reaction Glucose + Proteins /nucleic acids/lipids Aldose Reductase (Hydrogenation) Hydrolysis Sorbitol Fructose Triose phosphate Keton bodies Sorbitol dehydrogenase PUFAs/membrane lipids Detoxified by glyoxalaseI/II aldehyde─dehydrogenase and others Peroxylradical Fructose─3─phosphokinase Fructose─3─phosphate Polyol pathway Lipid peroxidation Detoxified by fruectosamine 3─phosphokirase (F3NK) Fructosamine irreversible irreversible Reactive α─oxathaklehyde Glyoxal, methylglyoxal, 3─desoyglucosaon SCHIFF Base (ddimin) ADVANCED GLYCATION END PRODUCTS DOLD, CEL, MOLD, CML, GOLD, Pyrraline ROS Transition metal Amadori Product⎫⎬⎭図 2 AGEsが関連する疾患と統合失調症の合併症リスク AGEs は,さまざまな疾患とも関連(左図)し,統合失調症の身体合併症のリスク要因(右図)とも関連している可能性がある。内分泌・代謝疾患神経変性疾患骨疾患呼吸器疾患腎疾患循環器疾患精神疾患糖化AGEs肥満喫煙糖尿病偏食高血圧骨折動脈硬化症耐糖能異常閉塞性肺疾患性機能障害脂質代謝異常メタボリックシンドローム喫煙糖尿病偏食骨折動脈硬化症耐糖能異常閉塞性肺疾患性機能障害脂質代謝異常メタボリックシンドローム統合失調症の患者を取り巻く要因循環器疾患内分泌・代謝疾患神経変性疾患腎疾患精神疾患
# 3 30 Japanese Journal of Biological Psychiatry Vol.26, No.1, 2015た16)。 AGEs は,主に AGEs 受容体(receptor for AGE: RAGE)に結合し,ミクログリアの活性化,NF ─κ Bを主体とした炎症反応,サイトカイン放出あるいはレドックス関連遺伝子の発現変化などを惹起する19)。この AGEs ─RAGE 系は,カルボニルストレスを制御する重要な代謝経路と考えられる。末梢血中での AGEs 蓄積が認められた統合失調症では,末梢ばかりでなく脳内においても AGEs と RAGE 経路の曝露が生じ,カルボニルストレスを助長している可能性も推測される。実際,ヒト剖検脳組織でのペントシジンの脳内蓄積を検討したところ,統合失調症群の前頭葉において,ペントシジン蓄積が対照と比較して高値である症例が存在すること,また,海馬領域における検討においてもペントシジン蓄積を認めている。カルボニルストレスの脳内局在化とAGEs─RAGE 経路を介したシグナリングがどのような関連があるのか,また,炎症性分子産生の上昇やその他 AGEs の蓄積についても継続した検討が不可欠である。今後,末梢血 ─ 剖検脳(病理)の相互での詳細な AGEs プロファイリングを実施することが病態解明への糸口となる。3.カルボニルストレスと認知機能 統合失調症は,認知機能の低下によりさまざまな社会生活機能が障害される精神疾患である。近年では地域社会へ根ざした精神科医療が推進されているため,患者が地域社会で自立した生活を送れるように認知機能障害の回復に焦点を当てた研究が活発化してきている。しかし,統合失調症における認知機能障害の分子メカニズムはいまだ明らかにされていない部分が多く,有効な治療法も確立されていないのが現状である。筆者らは,このカルボニルストレス性統合失調症患者を対象に,ピリドキサミンの投与によるカルボニルストレスの除去を治療標的とした臨床試験を実施した。その結果,PANSS の陰性症状が有意に低下しただけでなく,被験者の疎通性の改善,現実検討力の回復が認められたことから,カルボニルストレスと統合失調症の認知機能障害の間に関連が示唆された。 そこで,筆者らは,カルボニルストレスを呈する症例では認知機能の低下が認められるのではないかという作業仮説をたて,予備的な検討を行った。統合失調症と診断された 29 症例を 4 グループに分類(グループI,正常ペントシジン値・正常ビタミンB6 値;グループII,正常ペントシジン値・ビタミン B6 低値;グループIII,ペントシジン高値・ビタミン B6 正常値;グループIV,ペントシジン高値・ビタミン B6 低値)し,臨床症状の重症度についてマンチェスタースケール日本語版にて評価し,認知機能についてウェクスラー成人知能検査第 3 版(合理的に考え,効率的に環境と接する個人の総体的能力を評価),およびウィスコンシンカード分類課題(強化学習の状況の変化に直面した際の柔軟さを意味するセットシフティングの能力を評価)を実施した。その結果,カルボニルストレス性統合失調症では作動記憶や即時記憶が影響を受ける可能性があり,ビタミン B6 の減少と作動記憶の間に関連性が示唆された(小堀ら,投稿準備中)。各種マーカーと臨床症状,経過,認知機能との関連を明らかにし,患者の QOL の向上および社会復帰促進につながる成果を得ることは,今後ますます重要である。特定マーカーと関連する認知機能の特徴を把握することで,認知機能障害の改善を目指し,個別化医療実現へ応用も可能となる。症例の病態の多様性を分析し,病状把握,予後予測や心理的介入に有用な情報を明らかにすることができれば,認知機能障害を予防する貴重な臨床学的知見となりうる。4.統合失調症とビタミン 糖尿病や心疾患などの発症には,遺伝的な素因に加えて栄養学的諸問題をも内包している。また,栄養摂取における消化・吸収・貯蔵・代謝など何らかの機能的不全,栄養過多や栄養バランスの乱れは身体に対し重大な障害を招く場合もある。ビタミンB6 には,ピリドキシン,ピリドキサール,ピリドキサミンがあり水溶性ビタミンに分類される生理活性物質でもある9)。日本人の食事摂取基準としての推奨量は,0.5 ~ 1.4mg/day とされている。生体内ではこれらのリン酸エステル型であるピリドキシン─5 ─リン酸,ピリドキサール─5 ─リン酸,ピリドキサミン─5 ─リン酸として存在し,アミノ酸代謝や神経伝達物質の生成など,100 種類以上の酵素の補酵素として作用している。特に,アミノ基転移反応,ドーパミン,アドレナリン,セロトニンなどの生理活性アミンの合成に必須の脱炭酸反応,さらには,グリコーゲン分解のホスホリラーゼの重要な構成成分でもある。 栄養学と遺伝学相互の観点からの解析は,ビタミン欠乏の予防のための効果的な栄養素の摂取あるいはビタミン補充療法への糸口となることが期待される。これまでの研究から,およそ 2 割の統合失調
# 4 31日本生物学的精神医学会誌 26 巻 1 号症の病態にカルボニルストレスが関連し,これらの症例ではビタミン B6 が欠乏していた。特に,統合失調症患者 45 例中 26 例(57.8%)では,ビタミンB6 欠乏が認められ,その一方,健常者のビタミンB6 欠乏はおよそ 10%以下に留まっていた。この所見は,ビタミン B6 欠乏が統合失調症のリスク要因になっていること,カルボニルストレス性統合失調症に対してビタミン B6 の補充療法が症状改善に有効である可能性が高いと考えられた。5.治療,予防薬としてのピリドキサミン AGEs の形成阻害薬またはカルボニル化合物捕捉薬は,カルボニルストレスを直接的に回避することが期待できる。特に,統合失調症の徴候および症状にカルボニルストレスが関連している場合,治療効果が期待される。筆者らは,これまでに,統合失調症患者に対するピリドキサミンを使用した医師主導型の臨床試験を実施した(UMIN000006398:Clinical pharmacological trial of TM8001 for schizophrenia associated with carbonyl stress)。ペントシジン高値の 10 症例に対して,ピリドキサミンを経口投与(初期投与量は 1200mg/day)し,投与量をペントシジン値およびピリドキサミン値に応じて,1,800mg/ day および 2,400mg/day にまで増減した。安全性および有効性の評価試験として,観察期間を 6 ヵ月間として設けた。その結果,10 症例のうち 6 例ではおよそ 10%以上のペントシジン値の減少を示し,かつ,統計的に試験後の平均ペントシジン値は,治験前よりも有意に低下していることが明らかとなった。独立した 2 人の精神科医による臨床評価においては,大半の患者で,睡眠改善,攻撃性の減少を認め,また,投与開始後の比較的早い段階において,会話および自発運動量の増加を示した。さらに,被験者の半数例では薬剤誘発性錐体外路症状の改善を示した。 カルボニルストレスは,統合失調症の亜集団における病理学的メカニズムを解明するための重要な概念であり,ピリドキサミン処理はカルボニルストレス性の患者のための個別化医療に適合できると考えられる。将来的には早期介入への適用の可能性を探るため,AGEs の産生抑制能,カルボニル化合物補足能を有する天然物の同定は,より早期からの予防と発症の回避につながると期待される。6.運動療法によるカルボニルストレス回避 筆者らは,身体運動による適切なエビデンスに基づく,当事者の心身の健康の回復への取り組みを実施することを開始した。統合失調症の発症には遺伝─環境因子が複雑に関与し,適切な治療方法が定まらずに入退院を繰り返し慢性化した症状に苦しむ患者も少なくない。ヨーガ療法は,インド,欧米を中心に医療大学病院等で臨床導入や研究が行なわれている運動療法の一つである。ヨーガ療法の奏功機序については不明な点も多いものの,その有効性は,乳ガン患者の QOL の向上や疲労感とコルチゾールの減少4),産褥うつ患者のうつ状態・心配・怒りと背中・足痛やコルチゾール等の減少5),2 型糖尿病での BMI と血糖減少,酸化ストレスマーカーの減少,グルタチオンとビタミン C レベルの増加8)などが報告されている。また,健常者を対象とした研究からも,脳画像解析に基づく GABA の増加と運動誘発性気分の向上,不安の減少24)などが報告されている。筆者らは,現在,思春期,成人期に好発する病に対し,ヨーガ療法の介入効果を分子生物学的な機序という側面から解析を進めている。近い将来,統合失調症に対するヨーガ療法にとどまらず,精神疾患の当事者が抱える身体合併症の回避にも波及する介入方法を明らかにすることができれば,精神的な健康の増進はもとより社会全体にとっても大きな意義があると考えている。おわりに 統合失調症患者に同定した「カルボニルストレス」はバイオマーカーとしての有用性に加え,統合失調症における代謝制御システムの失調機構解明,発症リスクの回避に向けた医薬品開発につながる可能性が期待される。また,認知機能や QOL,ADL の改善と AGEs マーカーとの関連がより明確となれば,当事者が希求する早期診断,治療,予防法開発の進展につながる。in vitro から in vivo の包括的なデータベース構築によって,症例個々あるいは均質な症例群の病因と病態理解に資する成果を十分に挙げることができれば,個別化医療の理解が加速し,心身の改善へ貢献ができるものと考えている。 本稿の内容の一部は,第 36 回日本生物学的精神医学会・第 57 回日本神経化学会大会合同年会「シンポジウム 15:酸化ストレス・炎症と精神疾患」にて発表した。また,本稿で紹介した研究が統合失調症の本体解明の一助に寄与することを願い,当事
# 5 32 Japanese Journal of Biological Psychiatry Vol.26, No.1, 2015者の社会復帰を大きく助け,家族や職場などをとりまく環境の改善効果が向上させることを期待したい。本研究は,東京都医学総合研究所および関連施設の倫理委員会の承認を得て,被験者にインフォームドコンセントを得て実施された。文 献 1 ) Arai M, Koike S, Oshima N, et al(2011)Idiopathic carbonyl stress in a drug ─ naive case of at ─ risk mental state. Psychiatry Clin Neurosci, 65(6):606 ─607.  2 ) Arai M, Miyashita M, Kobori A, et al(2014) Carbonyl stress and schizophrenia. Psychiatry Clin Neurosci, 68(9):655 ─665.  3 ) Arai M, Yuzawa H, Nohara I, et al(2010)Enhanced carbonyl stress in a subpopulation of schizophrenia. Arch Gen Psychiatry, 67(6):589 ─597.  4 ) Chandwani KD, Perkins G, Nagendra HR, et al(2014) Randomized, controlled trial of yoga in women with breast cancer undergoing radiotherapy. J Clin Oncol, 32(10):1058 ─1065.  5 ) Field T, Diego M, Delgado J, et al(2013)Yoga and social support reduce prenatal depression, anxiety and cortisol. J Bodyw Mov Ther, 17(4):397 ─403.  6 ) Fujimoto M, Uchida S, Watanuki T, et al(2008) Reduced expression of glyoxalase ─1 mRNA in mood disorder patients. Neurosci Lett, 438(2):196 ─199.  7 ) Goldin A, Beckman JA, Schmidt AM, et al(2006) Advanced glycation end products:sparking the development of diabetic vascular injury. Circulation, 114(6):597 ─605.  8 ) Hegde SV, Adhikari P, Kotian S, et al(2011)Effect of 3 ─ month yoga on oxidative stress in type 2 diabetes with or without complications:a controlled clinical trial. Diabetes Care, (10):2208 ─2210.  9 ) Hellmann H and Mooney S(2010)Vitamin B6:a molecule for human health? Molecules, 15(1):442 ─459. 10) Jaisson S and Giller y P(2010)Evaluation of nonenzymatic posttranslational modification ─derived products as biomarkers of molecular aging of proteins. Clin Chem, 56(9):1401 ─1412. 11) Junaid MA, Kowal D, Barua M, et al(2014) Proteomic studies identified a single nucleotide polymorphism in glyoxalase I as autism susceptibility factor. Am J Med Genet A, 131(1):11 ─17. 12) Katsuta N, Ohnuma T, Maeshima H, et al(2014) Significance of measurements of peripheral carbonyl stress markers in a cross ─sectional and longitudinal study in patients with acute ─ stage schizophrenia. Schizophr Bull, 40(6):1366 ─1373. 13) Kouidrat Y, Amad A, Desailloud R, et al(2013) Increased advanced glycation end ─products(AGEs) assessed by skin autofluorescence in schizophrenia. J Psychiatr Res, 47(8):1044 ─1048. 14) Kuhla B, Boeck K, Schmidt A, et al(2007)Age ─and stage ─ dependent glyoxalase I expression and its activity in normal and Alzheimer’s disease brains. Neurobiol Aging, 28(1):29 ─41. 15) Ledig M, Doffoel M, Ziessel M, et al(1986) Frequencies of glyoxalase I phenotypes as biological markers in chronic alcoholism. Alcohol, 3(1):11 ─14. 16) Miyashita M, Arai M, Kobori A, et al(2014)Clinical features of schizophrenia with enhanced carbonyl stress. Schizophr Bull, 40(5):1040 ─1046. 17) Miyashita M, Arai M, Yuzawa H, et al(2014) Replication of enhanced carbonyl stress in a subpopulation of schizophrenia. Psychiatry Clin Neurosci, 68(1):83 ─84. 18) Miyata T, van Ypersele de Strihou C, Imasawa T, et al (2001)Glyoxalase I deficiency is associated with an unusual level of advanced glycation end products in a hemodialysis patient. Kidney Int, 60(6):2351 ─2359. 19) Ott C, Jacobs K, Haucke E, et al(2014)Role of advanced glycation end products in cellular signaling. Redox Biol, 2:411 ─429. 20) Politi P, Minoretti P, Falcone C, et al(2006) Association analysis of the functional Ala111Glu polymorphism of the glyoxalase I gene in panic disorder. Neurosci Lett, 396(2):163 ─166. 21) Rabbani N, Sebekova K, Sebekova K Jr, et al(2007) Accumulation of free adduct glycation, oxidation, and nitration products follows acute loss of renal function. Kidney Int, 72(9):1113 ─1121. 22) Rabbani N and Thornalley PJ(2012)Glycation research in amino acids:a place to call home. Amino Acids, 42(4):1087 ─1096. 23) Sawa A and Seidman LJ(2014)Is prophylactic psychiatry around the corner? combating adolescent oxidative stress for adult psychosis and sc ...
# 6 33日本生物学的精神医学会誌 26 巻 1 号Effects of yoga versus walking on mood, anxiety, and brain GABA levels:a randomized controlled MRS study. J Altern Complement Med, 16(11):1145 ─1152. 25) Toyosima M, Maekawa M, Toyota T, et al(2011) Schizophrenia with the 22q11. 2 deletion and additional genetic defects:case histor y. Br J Psychiatry, 199(3):245 ─246. 26) Yao JK and Keshavan MS(2011)Antioxidants, redox signaling, and pathophysiology in schizophrenia: an integrative view. Antioxid Redox Signal, 15(7): 2011 ─2035. ■ ABSTRACT Carbonyl stress dysfunction in a subpopulation of schizophrenia Makoto Arai,Akiko Kobori,Mitsuhiro Miyashita,Kazuya Toriumi, Yasue Horiuchi,Sachiko Hatakeyama,Miki Uchida,Tomoko Inoue,Masanari Itokawa Department of Psychiatry and Behavioral Sciences, Tokyo Metropolitan Institute of Medical Science We previously reported that a certain subtype of schizophrenic patients exhibit idiopathic carbonyl stress with high plasma pentosidine levels and serum vitamin B6 depletion, which is referred to as carbonyl stress, without underlying diabetes or chronic kidney disease that are the two major cause of elevation of advanced glycation end products(AGEs). Furthermore, we found the correlation between carbonyl stress and clinical features such as high ratio of inpatients, long duration of hospitalization, higher daily doses of anti ─ psychotics and lower educational status, suggesting that those patients might be treatment ─ registrant cases. We attempted to find associations between cognitive impairments and biochemical data. Schizophrenics were divided into four groups by their levels of pentosidine and vitamin B6, and we assessed the symptom severity by the Manchester Scale Japanese version, the cognitive function by Wechsler Adult Intelligence Scale 3rd version and Wisconsin card sorting test. We found that symptoms in high ─ risk group with high pentosidine and low vitamin B6 had a tendency to severe incoherence of thought and lower performance for digit span compared to that of other groups. Our preliminary data suggest that carbonyl stress might be associated with impaired working memory in schizophrenia. The comprehensive information covering in vitro and in vivo studies is important for evidence ─based personalized for schizophrenic patients.  (Japanese Journal of Biological Psychiatry 26(1):27 ─33, 2015)

# %%
langdetect.detect(t)
# Out:
# 'en'
